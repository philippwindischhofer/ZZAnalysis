# %%
import sys, os
sys.path.insert(0, '/home/llr/cms/wind/cmssw/CMSSW_9_4_2/src/ZZAnalysis/AnalysisStep/test/Python/')

# %%
from trainlib.ConfigFileHandler import ConfigFileHandler
from trainlib.ModelCollectionConfigFileHandler import ModelCollectionConfigFileHandler
# Out:
# Welcome to JupyROOT 6.10/09
# Using TensorFlow backend.

# %%
from vis.losses import ActivationMaximization

# %%
from keras import backend as K
import matplotlib.pyplot as plt
import numpy as np

# %%
K.set_learning_phase(False)

# %%
def get_model(run_dir, model_name):
    confhandler = ModelCollectionConfigFileHandler()
    confhandler.load_configuration(os.path.join(run_dir, "settings.conf"))
    
    mcolls = confhandler.GetModelCollection(weightpath = os.path.join(run_dir, "training/"))
    
    for mcoll in mcolls:
        if model_name in mcoll.model_dict.keys():
            found_mcoll = mcoll
            model = mcoll.model_dict[model_name]
            pre = mcoll.preprocessor_dict[model_name]
            break
        
    return model, pre

# %%
# load the neural network that is to be visualized
#run_dir = "/data_CMS/cms/wind/180515_ZX_qq_nomela/number_layers_2.0_number_neurons_64.0/"
#run_dir = "/data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/"
run_dir = "/data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/"
model_name = "D_ZHl_ZX_ML"
#model_name = "D_VBF_ggH_2j_ML"
#model_name = "D_VBF_WHh_ML"

# %%
model, pre = get_model(run_dir, model_name)
# Out:
# attempting to load configuration file from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/settings.conf
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 11 inputs
# FlexiblePCAPreprocessor set up for 11 inputs
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 16 inputs
# FlexiblePCAPreprocessor set up for 16 inputs
# found the following models belonging to this collection:
# D_VBF_ggH_2j_ML
# D_VBF_ggH_0j_ML
# D_VBF_ggH_1j_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_2j_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_2j_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_2j_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_ggH_2j_ML_input': Index([       u'JetPt_2',          u'PFMET', u'D_VBF2j_ZHh_ME',
#        u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',   u'D_WHh_ggH_ME',       u'D_bkg_ME',
#          u'D_ZHh_ggH_ME',         u'Z1Mass',           u'Z2Pt',
#               u'JetPt_1',       u'JetEta_2',           u'ZZPt',
#          u'D_WHh_ZHh_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_2_sin',   u'JetPhi_2_cos',   u'JetPhi_0_sin',
#          u'JetPhi_0_cos',      u'ZZPhi_sin',      u'ZZPhi_cos',
#          u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_ggH_2j_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_2j_ML/preprocessor.pkl
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_0j_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_0j_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_0j_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_ggH_0j_ML_input': Index([u'PFMET', u'D_bkg_ME', u'Z2Mass', u'ZZPt', u'Z1Mass', u'Z1Pt',
#        u'ZZMassErr', u'ZZEta', u'Z2Pt', u'ZZPhi_sin', u'ZZPhi_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_ggH_0j_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_0j_ML/preprocessor.pkl
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_1j_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_1j_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_1j_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_ggH_1j_ML_input': Index([         u'PFMET',        u'JetPt_0',         u'Z2Mass',
#                  u'Z1Pt',      u'ZZMassErr',       u'D_bkg_ME',
#                u'Z1Mass',           u'Z2Pt',           u'ZZPt',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_ggH_1j_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_1j_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# found the following models belonging to this collection:
# D_WHh_ggH_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_ggH_ML/D_WHh_ggH_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_ggH_ML/D_WHh_ggH_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_ggH_ML/D_WHh_ggH_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHh_ggH_ML_input': Index([       u'JetPt_2',          u'PFMET', u'D_VBF2j_ZHh_ME',
#        u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',   u'D_WHh_ggH_ME',       u'D_bkg_ME',
#          u'D_ZHh_ggH_ME',         u'Z1Mass',           u'Z2Pt',
#               u'JetPt_1',       u'JetEta_2',           u'ZZPt',
#          u'D_WHh_ZHh_ME', u'D_VBF1j_ggH_ME',          u'ZZEta',
#              u'JetEta_0',   u'JetPhi_0_sin',   u'JetPhi_0_cos',
#             u'ZZPhi_sin',      u'ZZPhi_cos',   u'JetPhi_1_sin',
#          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHh_ggH_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_ggH_ML/D_WHh_ggH_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# found the following models belonging to this collection:
# D_ZHh_ggH_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ggH_ML/D_ZHh_ggH_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ggH_ML/D_ZHh_ggH_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ggH_ML/D_ZHh_ggH_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ggH_ML_input': Index([                       u'JetPt_2',                          u'PFMET',
#                        u'D_VBF2j_ZHh_ME',                 u'D_VBF2j_WHh_ME',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                   u'D_WHh_ggH_ME',
#                              u'D_bkg_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                               u'JetPt_1',                       u'JetEta_2',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ggH_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ggH_ML/D_ZHh_ggH_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# found the following models belonging to this collection:
# D_WHh_ZHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_ZHh_ML/D_WHh_ZHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_ZHh_ML/D_WHh_ZHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_ZHh_ML/D_WHh_ZHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHh_ZHh_ML_input': Index([                       u'JetPt_2',                          u'PFMET',
#                        u'D_VBF2j_ZHh_ME',                 u'D_VBF2j_WHh_ME',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                       u'JetEta_3',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                       u'D_bkg_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                        u'JetPt_1',
#                              u'JetEta_2',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_2_sin',                   u'JetPhi_2_cos',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHh_ZHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_ZHh_ML/D_WHh_ZHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# found the following models belonging to this collection:
# D_VBF_WHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_WHh_ML/D_VBF_WHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_WHh_ML/D_VBF_WHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_WHh_ML/D_VBF_WHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_WHh_ML_input': Index([       u'JetPt_2',          u'PFMET', u'D_VBF2j_ZHh_ME',
#        u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',   u'D_WHh_ggH_ME',       u'D_bkg_ME',
#          u'D_ZHh_ggH_ME',         u'Z1Mass',           u'Z2Pt',
#               u'JetPt_1',       u'JetEta_2',           u'ZZPt',
#          u'D_WHh_ZHh_ME', u'D_VBF1j_ggH_ME',          u'ZZEta',
#              u'JetEta_0',   u'JetPhi_2_sin',   u'JetPhi_2_cos',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',   u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_WHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_WHh_ML/D_VBF_WHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# found the following models belonging to this collection:
# D_VBF_ZHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ZHh_ML/D_VBF_ZHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ZHh_ML/D_VBF_ZHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ZHh_ML/D_VBF_ZHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_ZHh_ML_input': Index([                       u'JetPt_2',                          u'PFMET',
#                        u'D_VBF2j_ZHh_ME',                 u'D_VBF2j_WHh_ME',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                        u'JetPt_1',
#                          u'D_WHh_ggH_ME',                       u'D_bkg_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                       u'JetEta_2',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_2_sin',
#                          u'JetPhi_2_cos',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_ZHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_ZHh_ML/D_VBF_ZHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 22 inputs
# FlexiblePCAPreprocessor set up for 22 inputs
# found the following models belonging to this collection:
# D_WHl_ggH_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ggH_ML/D_WHl_ggH_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ggH_ML/D_WHl_ggH_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ggH_ML/D_WHl_ggH_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ggH_ML_input': Index([    u'ZZMass_masked',             u'PFMET',      u'ExtraLepPt_0',
#                  u'JetPt_0',            u'Z2Mass',              u'Z1Pt',
#                u'ZZMassErr',     u'ExtraLepEta_0',          u'D_bkg_ME',
#                   u'Z1Mass',              u'Z2Pt',              u'ZZPt',
#             u'D_WHh_ZHh_ME',    u'D_VBF1j_ggH_ME',             u'ZZEta',
#                 u'JetEta_0',      u'JetPhi_0_sin',      u'JetPhi_0_cos',
#                u'ZZPhi_sin',         u'ZZPhi_cos', u'ExtraLepPhi_0_sin',
#        u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ggH_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ggH_ML/D_WHl_ggH_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# found the following models belonging to this collection:
# D_WHl_VBF_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_VBF_ML/D_WHl_VBF_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_VBF_ML/D_WHl_VBF_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_VBF_ML/D_WHl_VBF_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_VBF_ML_input': Index([ u'ZZMass_masked',          u'PFMET',   u'ExtraLepPt_0',
#        u'D_VBF2j_ZHh_ME', u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',
#               u'JetPt_0',         u'Z2Mass',       u'JetEta_1',
#                  u'Z1Pt',      u'ZZMassErr',  u'ExtraLepEta_0',
#              u'D_bkg_ME',   u'D_ZHh_ggH_ME',         u'Z1Mass',
#                  u'Z2Pt',        u'JetPt_1',           u'ZZPt',
#          u'D_WHh_ZHh_ME', u'D_VBF1j_ggH_ME',          u'ZZEta',
#              u'JetEta_0',   u'JetPhi_2_sin',   u'JetPhi_2_cos',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',   u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_VBF_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_VBF_ML/D_WHl_VBF_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# found the following models belonging to this collection:
# D_WHl_WHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_WHh_ML/D_WHl_WHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_WHh_ML/D_WHl_WHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_WHh_ML/D_WHl_WHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_WHh_ML_input': Index([    u'ZZMass_masked',           u'JetPt_2',             u'PFMET',
#             u'ExtraLepPt_0',    u'D_VBF2j_WHh_ME',    u'D_VBF2j_ggH_ME',
#                  u'JetPt_0',            u'Z2Mass',          u'JetEta_1',
#                     u'Z1Pt',         u'ZZMassErr',      u'D_WHh_ggH_ME',
#            u'ExtraLepEta_0',          u'D_bkg_ME',      u'D_ZHh_ggH_ME',
#                   u'Z1Mass',              u'Z2Pt',           u'JetPt_1',
#                     u'ZZPt',      u'D_WHh_ZHh_ME',    u'D_VBF1j_ggH_ME',
#                    u'ZZEta',          u'JetEta_0',      u'JetPhi_0_sin',
#             u'JetPhi_0_cos',         u'ZZPhi_sin',         u'ZZPhi_cos',
#             u'JetPhi_1_sin',      u'JetPhi_1_cos', u'ExtraLepPhi_0_sin',
#        u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_WHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_WHh_ML/D_WHl_WHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# found the following models belonging to this collection:
# D_WHl_ZHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHh_ML/D_WHl_ZHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHh_ML/D_WHl_ZHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHh_ML/D_WHl_ZHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ZHh_ML_input': Index([                 u'ZZMass_masked',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_WHh_ME',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                   u'D_WHh_ggH_ME',
#                              u'D_bkg_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                               u'JetPt_1',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                     u'ExtraLepPhi_0_sin',              u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ZHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHh_ML/D_WHl_ZHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 25 inputs
# FlexiblePCAPreprocessor set up for 25 inputs
# found the following models belonging to this collection:
# D_WHl_ZHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHl_ML/D_WHl_ZHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHl_ML/D_WHl_ZHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHl_ML/D_WHl_ZHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ZHl_ML_input': Index([    u'ZZMass_masked',         u'nExtraLep',             u'PFMET',
#             u'ExtraLepPt_0',    u'D_VBF2j_ggH_ME',           u'JetPt_0',
#                   u'Z2Mass',              u'Z1Pt',         u'ZZMassErr',
#            u'ExtraLepEta_0',          u'D_bkg_ME',      u'D_ZHh_ggH_ME',
#                   u'Z1Mass',              u'Z2Pt',              u'ZZPt',
#             u'D_WHh_ZHh_ME',    u'D_VBF1j_ggH_ME',             u'ZZEta',
#                 u'JetEta_0',      u'JetPhi_0_sin',      u'JetPhi_0_cos',
#                u'ZZPhi_sin',         u'ZZPhi_cos', u'ExtraLepPhi_0_sin',
#        u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ZHl_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHl_ML/D_WHl_ZHl_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 26 inputs
# FlexiblePCAPreprocessor set up for 26 inputs
# found the following models belonging to this collection:
# D_WHl_ZHMET_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHMET_ML/D_WHl_ZHMET_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHMET_ML/D_WHl_ZHMET_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHMET_ML/D_WHl_ZHMET_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ZHMET_ML_input': Index([    u'ZZMass_masked',         u'nExtraLep',             u'PFMET',
#             u'ExtraLepPt_0',           u'nExtraZ',           u'JetPt_0',
#                   u'Z2Mass',          u'JetEta_1',              u'Z1Pt',
#                u'ZZMassErr',     u'ExtraLepEta_0',          u'D_bkg_ME',
#                   u'Z1Mass',              u'Z2Pt',              u'ZZPt',
#           u'D_VBF1j_ggH_ME',             u'ZZEta',          u'JetEta_0',
#             u'JetPhi_0_sin',      u'JetPhi_0_cos',         u'ZZPhi_sin',
#                u'ZZPhi_cos',      u'JetPhi_1_sin',      u'JetPhi_1_cos',
#        u'ExtraLepPhi_0_sin', u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ZHMET_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHMET_ML/D_WHl_ZHMET_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# found the following models belonging to this collection:
# D_WHl_ttHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHh_ML/D_WHl_ttHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHh_ML/D_WHl_ttHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHh_ML/D_WHl_ttHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ttHh_ML_input': Index([                 u'ZZMass_masked',                      u'nExtraLep',
#                               u'JetPt_2',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ZHh_ME',
#                               u'JetPt_0',               u'nCleanedJetsPt30',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                   u'D_WHh_ggH_ME',
#                               u'JetPt_3',                       u'D_bkg_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                        u'JetPt_1',
#                              u'JetEta_2',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_2_sin',                   u'JetPhi_2_cos',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ttHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHh_ML/D_WHl_ttHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 34 inputs
# FlexiblePCAPreprocessor set up for 34 inputs
# found the following models belonging to this collection:
# D_WHl_ttHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHl_ML/D_WHl_ttHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHl_ML/D_WHl_ttHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHl_ML/D_WHl_ttHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ttHl_ML_input': Index([                 u'ZZMass_masked',                        u'JetPt_2',
#                                 u'PFMET',                   u'ExtraLepPt_0',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#                      u'nCleanedJetsPt30', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                        u'JetPt_3',
#                         u'ExtraLepEta_0',                       u'D_bkg_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                        u'JetPt_1',
#                          u'ExtraLepPt_1',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos',
#                     u'ExtraLepPhi_0_sin',              u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ttHl_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHl_ML/D_WHl_ttHl_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# found the following models belonging to this collection:
# D_ZHh_ZHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHl_ML/D_ZHh_ZHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHl_ML/D_ZHh_ZHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHl_ML/D_ZHh_ZHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ZHl_ML_input': Index([                 u'ZZMass_masked',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                               u'JetPt_1',                   u'D_WHh_ggH_ME',
#                              u'D_bkg_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ZHl_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHl_ML/D_ZHh_ZHl_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# found the following models belonging to this collection:
# D_ZHh_ZHMET_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHMET_ML/D_ZHh_ZHMET_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHMET_ML/D_ZHh_ZHMET_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHMET_ML/D_ZHh_ZHMET_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ZHMET_ML_input': Index([                       u'JetPt_2',                          u'PFMET',
#                        u'D_VBF2j_ZHh_ME',                 u'D_VBF2j_WHh_ME',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                        u'JetPt_1',
#                          u'D_WHh_ggH_ME',                       u'D_bkg_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ZHMET_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHMET_ML/D_ZHh_ZHMET_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 33 inputs
# FlexiblePCAPreprocessor set up for 33 inputs
# found the following models belonging to this collection:
# D_ZHh_ttHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHh_ML/D_ZHh_ttHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHh_ML/D_ZHh_ttHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHh_ML/D_ZHh_ttHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ttHh_ML_input': Index([                 u'ZZMass_masked',                        u'JetPt_2',
#                                 u'PFMET',                   u'ExtraLepPt_0',
#                        u'D_VBF2j_ZHh_ME',                 u'D_VBF2j_WHh_ME',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#                      u'nCleanedJetsPt30', u'nCleanedJetsPt30BTagged_bTagSF',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                   u'D_WHh_ggH_ME',
#                               u'JetPt_3',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                               u'JetPt_1',                       u'JetEta_2',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_2_sin',
#                          u'JetPhi_2_cos',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ttHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHh_ML/D_ZHh_ttHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 36 inputs
# FlexiblePCAPreprocessor set up for 36 inputs
# found the following models belonging to this collection:
# D_ZHh_ttHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHl_ML/D_ZHh_ttHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHl_ML/D_ZHh_ttHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHl_ML/D_ZHh_ttHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ttHl_ML_input': Index([                 u'ZZMass_masked',                      u'nExtraLep',
#                               u'JetPt_2',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ZHh_ME',
#                        u'D_VBF2j_WHh_ME',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0',               u'nCleanedJetsPt30',
#        u'nCleanedJetsPt30BTagged_bTagSF',                       u'JetEta_3',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                        u'JetPt_3',
#                              u'D_bkg_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                               u'JetPt_1',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_2_sin',                   u'JetPhi_2_cos',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ttHl_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHl_ML/D_ZHh_ttHl_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 24 inputs
# FlexiblePCAPreprocessor set up for 24 inputs
# found the following models belonging to this collection:
# D_ZHl_ggH_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ggH_ML/D_ZHl_ggH_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ggH_ML/D_ZHl_ggH_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ggH_ML/D_ZHl_ggH_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_ggH_ML_input': Index([ u'ZZMass_masked',          u'PFMET',   u'ExtraLepPt_0',
#        u'D_VBF2j_ggH_ME',        u'JetPt_0',         u'Z2Mass',
#                  u'Z1Pt',      u'ZZMassErr',  u'ExtraLepEta_0',
#              u'D_bkg_ME',   u'D_ZHh_ggH_ME',         u'Z1Mass',
#                  u'Z2Pt',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',   u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_ggH_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ggH_ML/D_ZHl_ggH_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# found the following models belonging to this collection:
# D_ZHl_VBF_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_VBF_ML/D_ZHl_VBF_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_VBF_ML/D_ZHl_VBF_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_VBF_ML/D_ZHl_VBF_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_VBF_ML_input': Index([ u'ZZMass_masked',        u'JetPt_2',          u'PFMET',
#          u'ExtraLepPt_0', u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',
#               u'JetPt_0',         u'Z2Mass',       u'JetEta_1',
#                  u'Z1Pt',      u'ZZMassErr',   u'D_WHh_ggH_ME',
#         u'ExtraLepEta_0',       u'D_bkg_ME',   u'D_ZHh_ggH_ME',
#                u'Z1Mass',           u'Z2Pt',       u'JetEta_2',
#                  u'ZZPt',   u'D_WHh_ZHh_ME', u'D_VBF1j_ggH_ME',
#                 u'ZZEta',       u'JetEta_0',   u'JetPhi_0_sin',
#          u'JetPhi_0_cos',      u'ZZPhi_sin',      u'ZZPhi_cos',
#          u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_VBF_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_VBF_ML/D_ZHl_VBF_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# found the following models belonging to this collection:
# D_ZHl_WHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_WHh_ML/D_ZHl_WHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_WHh_ML/D_ZHl_WHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_WHh_ML/D_ZHl_WHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_WHh_ML_input': Index([                 u'ZZMass_masked',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                               u'JetPt_1',                   u'D_WHh_ggH_ME',
#                              u'D_bkg_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_2_sin',
#                          u'JetPhi_2_cos',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_WHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_WHh_ML/D_ZHl_WHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# found the following models belonging to this collection:
# D_ZHl_ZHMET_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ZHMET_ML/D_ZHl_ZHMET_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ZHMET_ML/D_ZHl_ZHMET_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ZHMET_ML/D_ZHl_ZHMET_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_ZHMET_ML_input': Index([ u'ZZMass_masked',      u'nExtraLep',          u'PFMET',
#          u'ExtraLepPt_0', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',        u'JetPt_1',  u'ExtraLepEta_0',
#              u'D_bkg_ME',   u'D_ZHh_ggH_ME',         u'Z1Mass',
#                  u'Z2Pt',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',   u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_ZHMET_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ZHMET_ML/D_ZHl_ZHMET_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 35 inputs
# FlexiblePCAPreprocessor set up for 35 inputs
# found the following models belonging to this collection:
# D_ZHl_ttHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHh_ML/D_ZHl_ttHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHh_ML/D_ZHl_ttHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHh_ML/D_ZHl_ttHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_ttHh_ML_input': Index([                 u'ZZMass_masked',                        u'JetPt_2',
#                                 u'PFMET',                   u'ExtraLepPt_0',
#                        u'D_VBF2j_ZHh_ME',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0',               u'nCleanedJetsPt30',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                        u'JetPt_1',
#                          u'D_WHh_ggH_ME',                        u'JetPt_3',
#                              u'D_bkg_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                              u'JetEta_2',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_2_sin',
#                          u'JetPhi_2_cos',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos',                   u'JetPhi_3_sin',
#                          u'JetPhi_3_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_ttHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHh_ML/D_ZHl_ttHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# found the following models belonging to this collection:
# D_ZHl_ttHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHl_ML/D_ZHl_ttHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHl_ML/D_ZHl_ttHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHl_ML/D_ZHl_ttHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_ttHl_ML_input': Index([                 u'ZZMass_masked',                      u'nExtraLep',
#                               u'JetPt_2',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ZHh_ME',
# ...
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#         u'phistarZ1_sin',  u'phistarZ1_cos',   u'JetPhi_0_sin',
#          u'JetPhi_0_cos',      u'ZZPhi_sin',      u'ZZPhi_cos',
#            u'helphi_sin',     u'helphi_cos',     u'xistar_sin',
#            u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_qq_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_VBF_qq_ML/D_VBF_qq_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 33 inputs
# FlexiblePCAPreprocessor set up for 33 inputs
# found the following models belonging to this collection:
# D_ZHh_qq_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_qq_ML/D_ZHh_qq_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_qq_ML/D_ZHh_qq_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_qq_ML/D_ZHh_qq_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_qq_ML_input': Index([                 u'ZZMass_masked',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_WHh_ME',
#                               u'JetPt_0', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                       u'D_bkg_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                          u'costhetastar',                           u'Z2Pt',
#                         u'helcosthetaZ2',                  u'helcosthetaZ1',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                  u'phistarZ1_sin',
#                         u'phistarZ1_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                     u'helphi_sin',
#                            u'helphi_cos',                     u'xistar_sin',
#                            u'xistar_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_qq_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHh_qq_ML/D_ZHh_qq_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# found the following models belonging to this collection:
# D_ZHl_qq_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_qq_ML/D_ZHl_qq_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_qq_ML/D_ZHl_qq_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_qq_ML/D_ZHl_qq_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_qq_ML_input': Index([ u'ZZMass_masked',          u'PFMET',   u'ExtraLepPt_0',
#        u'D_VBF2j_ggH_ME',        u'JetPt_0',         u'Z2Mass',
#              u'JetEta_1',           u'Z1Pt',      u'ZZMassErr',
#          u'D_WHh_ggH_ME',       u'D_bkg_ME',         u'Z1Mass',
#          u'costhetastar',           u'Z2Pt',  u'helcosthetaZ2',
#         u'helcosthetaZ1',           u'ZZPt', u'D_VBF1j_ggH_ME',
#                 u'ZZEta',       u'JetEta_0',  u'phistarZ1_sin',
#         u'phistarZ1_cos',   u'JetPhi_0_sin',   u'JetPhi_0_cos',
#             u'ZZPhi_sin',      u'ZZPhi_cos',     u'helphi_sin',
#            u'helphi_cos',     u'xistar_sin',     u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_qq_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHl_qq_ML/D_ZHl_qq_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# found the following models belonging to this collection:
# D_WHh_qq_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_qq_ML/D_WHh_qq_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_qq_ML/D_WHh_qq_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_qq_ML/D_WHh_qq_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHh_qq_ML_input': Index([ u'ZZMass_masked',          u'PFMET',   u'ExtraLepPt_0',
#               u'JetPt_0',         u'Z2Mass',       u'JetEta_1',
#                  u'Z1Pt',      u'ZZMassErr',   u'D_WHh_ggH_ME',
#              u'D_bkg_ME',   u'D_ZHh_ggH_ME',         u'Z1Mass',
#          u'costhetastar',           u'Z2Pt',        u'JetPt_1',
#         u'helcosthetaZ2',  u'helcosthetaZ1',           u'ZZPt',
#          u'D_WHh_ZHh_ME', u'D_VBF1j_ggH_ME',          u'ZZEta',
#              u'JetEta_0',  u'phistarZ1_sin',  u'phistarZ1_cos',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',     u'helphi_sin',     u'helphi_cos',
#            u'xistar_sin',     u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHh_qq_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHh_qq_ML/D_WHh_qq_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# found the following models belonging to this collection:
# D_WHl_qq_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_qq_ML/D_WHl_qq_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_qq_ML/D_WHl_qq_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_qq_ML/D_WHl_qq_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_qq_ML_input': Index([ u'ZZMass_masked',      u'nExtraLep',          u'PFMET',
#          u'ExtraLepPt_0',        u'JetPt_0',         u'Z2Mass',
#                  u'Z1Pt',      u'ZZMassErr',  u'ExtraLepEta_0',
#              u'D_bkg_ME',         u'Z1Mass',   u'costhetastar',
#                  u'Z2Pt',  u'helcosthetaZ2',  u'helcosthetaZ1',
#                  u'ZZPt', u'D_VBF1j_ggH_ME',          u'ZZEta',
#              u'JetEta_0',  u'phistarZ1_sin',  u'phistarZ1_cos',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',     u'helphi_sin',     u'helphi_cos',
#            u'xistar_sin',     u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_qq_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_WHl_qq_ML/D_WHl_qq_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 24 inputs
# FlexiblePCAPreprocessor set up for 24 inputs
# found the following models belonging to this collection:
# D_ZHMET_qq_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHMET_qq_ML/D_ZHMET_qq_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHMET_qq_ML/D_ZHMET_qq_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHMET_qq_ML/D_ZHMET_qq_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHMET_qq_ML_input': Index([ u'ZZMass_masked',          u'PFMET', u'D_VBF2j_WHh_ME',
#               u'JetPt_0',         u'Z2Mass',           u'Z1Pt',
#             u'ZZMassErr',       u'D_bkg_ME',         u'Z1Mass',
#          u'costhetastar',           u'Z2Pt',  u'helcosthetaZ2',
#         u'helcosthetaZ1',           u'ZZPt', u'D_VBF1j_ggH_ME',
#                 u'ZZEta',  u'phistarZ1_sin',  u'phistarZ1_cos',
#             u'ZZPhi_sin',      u'ZZPhi_cos',     u'helphi_sin',
#            u'helphi_cos',     u'xistar_sin',     u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHMET_qq_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ZHMET_qq_ML/D_ZHMET_qq_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 36 inputs
# FlexiblePCAPreprocessor set up for 36 inputs
# found the following models belonging to this collection:
# D_ttHh_qq_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ttHh_qq_ML/D_ttHh_qq_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ttHh_qq_ML/D_ttHh_qq_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ttHh_qq_ML/D_ttHh_qq_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ttHh_qq_ML_input': Index([                 u'ZZMass_masked',                        u'JetPt_2',
#                                 u'PFMET',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0',               u'nCleanedJetsPt30',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                   u'D_WHh_ggH_ME',
#                               u'JetPt_3',                       u'D_bkg_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                          u'costhetastar',                           u'Z2Pt',
#                               u'JetPt_1',                  u'helcosthetaZ1',
#                              u'JetEta_2',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                            u'helphi_sin',                     u'helphi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos',
#                          u'JetPhi_3_sin',                   u'JetPhi_3_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ttHh_qq_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ttHh_qq_ML/D_ttHh_qq_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 35 inputs
# FlexiblePCAPreprocessor set up for 35 inputs
# found the following models belonging to this collection:
# D_ttHl_qq_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ttHl_qq_ML/D_ttHl_qq_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ttHl_qq_ML/D_ttHl_qq_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ttHl_qq_ML/D_ttHl_qq_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ttHl_qq_ML_input': Index([                 u'ZZMass_masked',                      u'nExtraLep',
#                               u'JetPt_2',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                       u'D_bkg_ME',
#                                u'Z1Mass',                   u'costhetastar',
#                                  u'Z2Pt',                        u'JetPt_1',
#                         u'helcosthetaZ2',                  u'helcosthetaZ1',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                  u'phistarZ1_sin',
#                         u'phistarZ1_cos',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                     u'helphi_sin',
#                            u'helphi_cos',                     u'xistar_sin',
#                            u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ttHl_qq_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_ttHl_qq_ML/D_ttHl_qq_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# found the following models belonging to this collection:
# D_bkg_qq_ML
# now attempting to load model from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_bkg_qq_ML/D_bkg_qq_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_bkg_qq_ML/D_bkg_qq_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_bkg_qq_ML/D_bkg_qq_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_bkg_qq_ML_input': Index([ u'ZZMass_masked',          u'PFMET',        u'JetPt_0',
#                u'Z2Mass',           u'Z1Pt',      u'ZZMassErr',
#              u'D_bkg_ME',         u'Z1Mass',   u'costhetastar',
#                  u'Z2Pt',         u'Z2Flav',  u'helcosthetaZ2',
#         u'helcosthetaZ1',           u'ZZPt', u'D_VBF1j_ggH_ME',
#                 u'ZZEta',       u'JetEta_0',  u'phistarZ1_sin',
#         u'phistarZ1_cos',   u'JetPhi_0_sin',   u'JetPhi_0_cos',
#             u'ZZPhi_sin',      u'ZZPhi_cos',     u'helphi_sin',
#            u'helphi_cos',     u'xistar_sin',     u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_bkg_qq_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180514_ZX_qq/number_layers_2.0_number_neurons_64.0/training/D_bkg_qq_ML/D_bkg_qq_ML/preprocessor.pkl
# UnboundLocalErrorTraceback (most recent call last)
# <ipython-input-31-702b3a4e37cc> in <module>()
# ----> 1 model, pre = get_model(run_dir, model_name)
#
# <ipython-input-6-ba7491b9a93a> in get_model(run_dir, model_name)
#      12             break
#      13
# ---> 14     return model, pre
#
# UnboundLocalError: local variable 'model' referenced before assignment

# %%
pre.processed_columns
# Out:
# Index([ u'ZZMass_masked',          u'PFMET',   u'ExtraLepPt_0',
#        u'D_VBF2j_ggH_ME',        u'JetPt_0',         u'Z2Mass',
#                  u'Z1Pt',      u'ZZMassErr',  u'ExtraLepEta_0',
#              u'D_bkg_ME',   u'D_ZHh_ggH_ME',         u'Z1Mass',
#                  u'Z2Pt',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',   u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')

# %%
keras_model = model.get_keras_model()

# %%
layer_dict = {layer.name: layer for layer in keras_model.layers}

# %%
layer_dict
# Out:
# {u'D_ZHl_ggH_ML_input': <keras.engine.topology.InputLayer at 0x7f3f5470ea10>,
#  'activation_70': <keras.layers.core.Activation at 0x7f3f54661810>,
#  'activation_71': <keras.layers.core.Activation at 0x7f3f54600690>,
#  'activation_72': <keras.layers.core.Activation at 0x7f3f5453c7d0>,
#  'batch_normalization_70': <keras.layers.normalization.BatchNormalization at 0x7f3f5466d550>,
#  'batch_normalization_71': <keras.layers.normalization.BatchNormalization at 0x7f3f5452f590>,
#  'batch_normalization_72': <keras.layers.normalization.BatchNormalization at 0x7f3f545508d0>,
#  'dense_70': <keras.layers.core.Dense at 0x7f3f546c8c90>,
#  'dense_71': <keras.layers.core.Dense at 0x7f3f54615790>,
#  'dense_72': <keras.layers.core.Dense at 0x7f3f545639d0>,
#  'dropout_70': <keras.layers.core.Dropout at 0x7f3f546c8950>,
#  'dropout_71': <keras.layers.core.Dropout at 0x7f3f545de650>,
#  'dropout_72': <keras.layers.core.Dropout at 0x7f3f544abcd0>,
#  'target': <keras.layers.core.Dense at 0x7f3f546c8d90>}

# %%
def normalize(x):
    return x / (K.sqrt(K.mean(K.square(x))) + K.epsilon())

# %%
layer_output = layer_dict["target"].output

# %%
inputs = keras_model.input

# %%
loss = K.mean(layer_output[0])

# %%
grads = K.gradients(loss, inputs)[0]
grads = normalize(grads)

# %%
iterate = K.function([inputs], [loss, grads])

# %%
stepsize = 0.1

# %%
def synthesize_input_from(cur_input, threshold):
    for i in range(200):
        cur_loss, cur_grads = iterate([cur_input])
        cur_input += stepsize * cur_grads

        if cur_loss > threshold:
            break
            
    pre_pca_inputs = pre.base_preprocessor.pca.inverse_transform(cur_input).flatten().tolist()
    synthesized_input = {key: val for (key, val) in zip(pre.processed_columns, pre_pca_inputs)}
    
    return synthesized_input

# %%
def synthesize_inputs(num_inputs, threshold):
    synthesized = []
    
    for i in range(num_inputs):
        # start from a random input
        cur_input = np.random.uniform(-2, 2, size = (1, keras_model.input_shape[1]))
        synthesized_input = synthesize_input_from(cur_input, threshold)
        
        synthesized.append(synthesized_input)
        
    return synthesized

# %%
def extract_column(input_dicts, colname):
    retval = [cur_dict[colname] for cur_dict in input_dicts]
    
    return retval

# %%
def make_activation_maximization_plot(x_column, y_column, x_label, y_label, x_range, y_range, threshold):
    synthesized = synthesize_inputs(10000, threshold = threshold)
    
    x_data = extract_column(synthesized, x_column)
    y_data = extract_column(synthesized, y_column)
    
    x_edges = np.linspace(*x_range)
    y_edges = np.linspace(*y_range)
    
    H, x_edges, y_edges = np.histogram2d(x_data, y_data, bins = (x_edges, y_edges))
    
    fig = plt.figure(figsize = (5, 5))
    ax = fig.add_subplot(111)

    cax = ax.imshow(H, interpolation = "nearest", cmap = "hot", origin = "low", 
                    extent=[x_edges[0], x_edges[-1], y_edges[0], y_edges[-1]])
    
    ax.set_xlabel(x_label, fontsize = 17)
    ax.set_ylabel(y_label, fontsize = 17)

    #fig.colorbar(cax)
    plt.tight_layout()

    return fig

# %%
outpath = "/data_CMS/cms/wind/ActivationMaximization/"

# %%
# for VBF/ggH w/ MELA

# %%
fig = make_activation_maximization_plot("D_VBF2j_ggH_ME", "D_VBF2j_ZHh_ME", 
                                        r'$\mathcal{D}_{\mathrm{VBF-2j, ggH}}^{\mathrm{ME}}$', 
                                        r'$\mathcal{D}_{\mathrm{VBF-2j, ZH-hadr}}^{\mathrm{ME}}$', 
                                        (0, 1, 60), (0, 1, 60), threshold = 0.3)
plt.savefig(os.path.join(outpath, "D_VBF_ggH_MELA_03.pdf"))

# %%
fig = make_activation_maximization_plot("D_VBF2j_ggH_ME", "D_VBF2j_ZHh_ME", 
                                        r'$\mathcal{D}_{\mathrm{VBF-2j, ggH}}^{\mathrm{ME}}$', 
                                        r'$\mathcal{D}_{\mathrm{VBF-2j, ZH-hadr}}^{\mathrm{ME}}$', 
                                        (0, 1, 60), (0, 1, 60), threshold = 0.5)
plt.savefig(os.path.join(outpath, "D_VBF_ggH_MELA_05.pdf"))

# %%
fig = make_activation_maximization_plot("D_VBF2j_ggH_ME", "D_VBF2j_ZHh_ME", 
                                        r'$\mathcal{D}_{\mathrm{VBF-2j, ggH}}^{\mathrm{ME}}$', 
                                        r'$\mathcal{D}_{\mathrm{VBF-2j, ZH-hadr}}^{\mathrm{ME}}$', 
                                        (0, 1, 60), (0, 1, 60), threshold = 0.7)
plt.savefig(os.path.join(outpath, "D_VBF_ggH_MELA_07.pdf"))

# %%
fig = make_activation_maximization_plot("D_VBF2j_ggH_ME", "D_VBF2j_ZHh_ME", 
                                        r'$\mathcal{D}_{\mathrm{VBF-2j, ggH}}^{\mathrm{ME}}$', 
                                        r'$\mathcal{D}_{\mathrm{VBF-2j, ZH-hadr}}^{\mathrm{ME}}$', 
                                        (0, 1, 60), (0, 1, 60), threshold = 0.9)
plt.savefig(os.path.join(outpath, "D_VBF_ggH_MELA_09.pdf"))

# %%
# for VBF/WHh w/ MELA

# %%
fig = make_activation_maximization_plot("JetEta_0", "JetEta_1", r'$\eta_{\,\,0}$', r'$\eta_{\,\,1}$', (-6, 6, 60), (-6, 6, 60), threshold = 0.7)
plt.savefig(os.path.join(outpath, "D_VBF_WHh_07.pdf"))

# %%
fig = make_activation_maximization_plot("JetEta_0", "JetEta_1", r'$\eta_{\,\,0}$', r'$\eta_{\,\,1}$', (-6, 6, 60), (-6, 6, 60), threshold = 1.0 - 1e-1)
plt.savefig(os.path.join(outpath, "D_VBF_WHh_09.pdf"))

# %%
fig = make_activation_maximization_plot("JetEta_0", "JetEta_1", r'$\eta_{\,\,0}$', r'$\eta_{\,\,1}$', (-6, 6, 60), (-6, 6, 60), threshold = 1.0 - 1e-2)
plt.savefig(os.path.join(outpath, "D_VBF_WHh_099.pdf"))

# %%
fig = make_activation_maximization_plot("JetEta_0", "JetEta_1", r'$\eta_{\,\,0}$', r'$\eta_{\,\,1}$', (-6, 6, 60), (-6, 6, 60), threshold = 1.0 - 1e-3)
plt.savefig(os.path.join(outpath, "D_VBF_WHh_0999.pdf"))

# %%
# for VBF/ggH w/o MELA

# %%
fig = make_activation_maximization_plot("JetEta_0", "JetEta_1", r'$\eta(j_{0})$', r'$\eta(j_{1})$', (-6, 6, 60), (-6, 6, 60), threshold = 0.5)
plt.savefig(os.path.join(outpath, "D_VBF_ggH_NOMELA_05.pdf"))
#plt.show()

# %%
fig = make_activation_maximization_plot("JetEta_0", "JetEta_1", r'$\eta(j_{0})$', r'$\eta(j_{1})$', (-6, 6, 60), (-6, 6, 60), threshold = 0.7)
plt.savefig(os.path.join(outpath, "D_VBF_ggH_NOMELA_07.pdf"))
#plt.show()

# %%
fig = make_activation_maximization_plot("JetEta_0", "JetEta_1", r'$\eta(j_{0})$', r'$\eta(j_{1})$', (-6, 6, 60), (-6, 6, 60), threshold = 0.9)
plt.savefig(os.path.join(outpath, "D_VBF_ggH_NOMELA_09.pdf"))
#plt.show()

# %%
fig = make_activation_maximization_plot("JetEta_0", "JetEta_1", r'$\eta(j_{0})$', r'$\eta(j_{1})$', (-6, 6, 60), (-6, 6, 60), threshold = 0.99)
plt.savefig(os.path.join(outpath, "D_VBF_ggH_NOMELA_099.pdf"))
#plt.show()

# %%
# for ZHl/ZX w/ MELA

# %%
fig = make_activation_maximization_plot("Z1Mass", "Z2Mass", r'$m(Z_1)$', r'$m(Z_2)$', (0, 150, 60), (0, 150, 60), threshold = 0.999)
plt.show()

# %%
fig = make_activation_maximization_plot("Z1Pt", "Z2Pt", r'$p_T(Z_1)$', r'$p_T(Z_2)$', (0, 200, 60), (0, 200, 60), threshold = 0.99)
plt.show()

# %%
fig = make_activation_maximization_plot("D_bkg_ME", "D_VBF2j_ggH_ME", "D_bkg_ME", "D_VBF2j_ggH_ME", (0, 1, 60), (0, 1, 60), threshold = 0.0)
plt.show()
