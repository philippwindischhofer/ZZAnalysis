# %%
import numpy as np

from matplotlib import pyplot as plt

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,
                                              ExpSineSquared, DotProduct,
                                              ConstantKernel)


kernels = [1.0 * Matern(length_scale=0.01, length_scale_bounds=(1e-1, 10.0),
                        nu=1.5)]

for fig_index, kernel in enumerate(kernels):
    # Specify Gaussian Process
    gp = GaussianProcessRegressor(kernel=kernel)

    # Plot prior
    plt.figure(fig_index, figsize=(8, 8))
    plt.subplot(2, 1, 1)
    X_ = np.linspace(0, 1, 100)
    y_mean, y_std = gp.predict(X_[:, np.newaxis], return_std=True)
    plt.plot(X_, y_mean, 'k', lw=3, zorder=9)
    plt.fill_between(X_, y_mean - y_std, y_mean + y_std,
                     alpha=0.2, color='k')
    y_samples = gp.sample_y(X_[:, np.newaxis], 10)
    plt.plot(X_, y_samples, lw=1)
    plt.xlim(0, 5)
    plt.ylim(-3, 3)
    plt.title("Prior (kernel:  %s)" % kernel, fontsize=12)




plt.show()

# %%
import math

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
import os

# %%
os.path.join("/data/abc", "def", "fgh/")
# Out:
# '/data/abc/def/fgh/'

# %%
test = {}

# %%
test["abc"].append(3)

# %%
test["abc"] = []

# %%
test
# Out:
# {'abc': [3]}

# %%
"abdc" in test
# Out:
# False

# %%
from trainlib.ConfigFileHandler import ConfigFileHandler

# %%
confhandler = ConfigFileHandler()

# %%
confhandler.load_configuration("/data_CMS/cms/wind/180423_Adam_optimized_inputs_64_reopt/number_layers_2.0_number_neurons_64.0/priors_tree/evaluations.txt")
# Out:
# attempting to load configuration file from /data_CMS/cms/wind/180423_Adam_optimized_inputs_64_reopt/number_layers_2.0_number_neurons_64.0/priors_tree/evaluations.txt

# %%
sect=confhandler.get_section("evaluation_0")

# %%
for field, value in sect.iteritems():
    print field
    print value
# Out:
# cost
# -0.627655027631
# ggh_prior
# 1.1555475462
# whhadr_prior
# 0.379607831931
# zhhadr_prior
# 0.791083326046
# whlept_prior
# 0.702053837801
# zhlept_prior
# 0.395643372407
# zhmet_prior
# 0.570468928854
# tthhadr_prior
# 0.304226143197
# tthlept_prior
# 0.724306245633
