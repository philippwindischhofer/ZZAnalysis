# %%
import os
import shutil
import numpy as np
import subprocess as sp

# %%
from trainlib.ConfigFileHandler import ConfigFileHandler
from trainlib.ModelCollectionConfigFileHandler import ModelCollectionConfigFileHandler
from DistributeTrainingSettings import distribute_training_settings
# Out:
# Welcome to JupyROOT 6.10/09
# Using TensorFlow backend.

# %%
# this looks through several training runs (e.g. as they originate from a hyperparameter sweep) and takes for each 
# model the best one that was encountered

# %%
def get_loss(run, mcoll, model):
    confhandler = ConfigFileHandler()
    confhandler.load_configuration(os.path.join(campaign_workspace, run, "training", mcoll, "model_benchmark.txt"))
    return float(confhandler.get_field(model, 'val_loss'))

# %%
campaign_workspace = "/data_CMS/cms/wind/"

# %%
# runs to check for (good) models (the first one passed is taken as reference run from which the available models
# are taken - it is expected that all others runs also follow this structure):
input_runs = ["180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0",
              "180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0",
              "180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0",
              "180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0",
              "180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0",
              "180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0",
              "180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0",
              "180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0",
              "180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0",
              "180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0",
              "180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0",
              "180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0",
              "180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0",
              "180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0",
              "180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0",
              "180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0"]

# %%
output_run = "180518_optimized_hyperparameters/optimized"

# %%
os.makedirs(os.path.join(campaign_workspace, output_run))

# %%
# load the available model names
reference_run = input_runs[0]
available_mcolls = os.walk(os.path.join(campaign_workspace, reference_run, "training")).next()[1]

# %%
mcolls_winning = []

# %%
for mcoll in available_mcolls:
    models = os.walk(os.path.join(campaign_workspace, reference_run, "training", mcoll)).next()[1]

    # load a representative version of the current model collection...
    mconfhandler = ModelCollectionConfigFileHandler()
    mconfhandler.load_configuration(os.path.join(campaign_workspace, reference_run, "settings_training", mcoll, "settings.conf"))
    mcoll_template = mconfhandler.GetModelCollection()[0]
    
    # ... but strip away all the actual model components
    mcoll_template.model_dict = {}
    mcoll_template.preprocessor_dict = {}
    mcoll_template.settings_dict = {}
    
    for model in models:
        # compare this model across the different runs
        losses = [get_loss(run, mcoll, model) for run in input_runs]

        winner = np.argmin(losses)
        
        winning_run = input_runs[winner]
        
        # copy the winning model into the output run
        shutil.copytree(os.path.join(campaign_workspace, winning_run, "training", mcoll, model),
                        os.path.join(campaign_workspace, output_run, "training", mcoll, model))

        print "--------------------------------------------"
        print " take " + model + " from " + winning_run
        print "--------------------------------------------"
        
        # load the winning model to keep track of its settings
        mconfhandler = ModelCollectionConfigFileHandler()
        mconfhandler.load_configuration(os.path.join(campaign_workspace, winning_run, "settings_training", mcoll, "settings.conf"))
        mcoll_winning = mconfhandler.GetModelCollection()[0]
        
        # then pull the winning model over into the template
        winning_model = mcoll_winning.model_dict[model]
        winning_preprocessor = mcoll_winning.preprocessor_dict[model]
        winning_settings = mcoll_winning.settings_dict[model]
        
        mcoll_template.add_model(winning_preprocessor, winning_model, winning_settings)
        
    mcolls_winning.append(mcoll_template)
    
# now save the put-together config file also into the output run
mconfhandler = ModelCollectionConfigFileHandler()
mconfhandler.ToConfiguration(mcolls_winning)
mconfhandler.save_configuration(os.path.join(campaign_workspace, output_run, "settings.conf"))
# Out:
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_VBF_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 11 inputs
# FlexiblePCAPreprocessor set up for 11 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 16 inputs
# FlexiblePCAPreprocessor set up for 16 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# --------------------------------------------
#  take D_VBF_ggH_2j_ML from 180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/settings_training/D_VBF_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 11 inputs
# FlexiblePCAPreprocessor set up for 11 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 16 inputs
# FlexiblePCAPreprocessor set up for 16 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# --------------------------------------------
#  take D_VBF_ggH_0j_ML from 180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_VBF_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 11 inputs
# FlexiblePCAPreprocessor set up for 11 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 16 inputs
# FlexiblePCAPreprocessor set up for 16 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_VBF_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_VBF_ggH_ML/model_benchmark.txt
# --------------------------------------------
#  take D_VBF_ggH_1j_ML from 180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/settings_training/D_VBF_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 16.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 16.0}
# building network with 11 inputs
# FlexiblePCAPreprocessor set up for 11 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 16.0}
# building network with 16 inputs
# FlexiblePCAPreprocessor set up for 16 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHh_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_WHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_WHh_ggH_ML/model_benchmark.txt
# --------------------------------------------
#  take D_WHh_ggH_ML from 180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/settings_training/D_WHh_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 48.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_ZHh_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_ZHh_ggH_ML/model_benchmark.txt
# --------------------------------------------
#  take D_ZHh_ggH_ML from 180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/settings_training/D_ZHh_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 48.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHh_ZHh_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_WHh_ZHh_ML/model_benchmark.txt
# --------------------------------------------
#  take D_WHh_ZHh_ML from 180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/settings_training/D_WHh_ZHh_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 3.0, u'number_neurons': 16.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_WHh_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_WHl_WHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_WHl_WHh_ML/model_benchmark.txt
# --------------------------------------------
#  take D_WHl_WHh_ML from 180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/settings_training/D_WHl_WHh_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_ZHh_ZHl_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_ZHh_ZHl_ML/model_benchmark.txt
# --------------------------------------------
#  take D_ZHh_ZHl_ML from 180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/settings_training/D_ZHh_ZHl_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_ZHMET_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 26 inputs
# FlexiblePCAPreprocessor set up for 26 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_WHl_ZHMET_ML/model_benchmark.txt
# --------------------------------------------
#  take D_WHl_ZHMET_ML from 180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/settings_training/D_WHl_ZHMET_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 32.0}
# building network with 26 inputs
# FlexiblePCAPreprocessor set up for 26 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_ZHl_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 25 inputs
# FlexiblePCAPreprocessor set up for 25 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_WHl_ZHl_ML/model_benchmark.txt
# --------------------------------------------
#  take D_WHl_ZHl_ML from 180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/settings_training/D_WHl_ZHl_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 64.0}
# building network with 25 inputs
# FlexiblePCAPreprocessor set up for 25 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_ZHh_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_WHl_ZHh_ML/model_benchmark.txt
# --------------------------------------------
#  take D_WHl_ZHh_ML from 180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/settings_training/D_WHl_ZHh_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_ttHh_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_WHl_ttHh_ML/model_benchmark.txt
# --------------------------------------------
#  take D_WHl_ttHh_ML from 180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_ttHh_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 22 inputs
# FlexiblePCAPreprocessor set up for 22 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_WHl_ggH_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_WHl_ggH_ML/model_benchmark.txt
# --------------------------------------------
#  take D_WHl_ggH_ML from 180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_ggH_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 22 inputs
# FlexiblePCAPreprocessor set up for 22 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_VBF_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHl_VBF_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHl_VBF_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHl_VBF_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHl_VBF_ML/model_benchmark.txt
# ...
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_ZX_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_ZX_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_ZX_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_ZX_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_ZX_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_ZX_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_ZX_qq_ML/model_benchmark.txt
# --------------------------------------------
#  take D_ZX_qq_ML from 180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/settings_training/D_ZX_qq_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_ttHh_qq_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 36 inputs
# FlexiblePCAPreprocessor set up for 36 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_ttHh_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_ttHh_qq_ML/model_benchmark.txt
# --------------------------------------------
#  take D_ttHh_qq_ML from 180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/settings_training/D_ttHh_qq_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 36 inputs
# FlexiblePCAPreprocessor set up for 36 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_ZHMET_qq_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 24 inputs
# FlexiblePCAPreprocessor set up for 24 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_ZHMET_qq_ML/model_benchmark.txt
# --------------------------------------------
#  take D_ZHMET_qq_ML from 180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/settings_training/D_ZHMET_qq_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 48.0}
# building network with 24 inputs
# FlexiblePCAPreprocessor set up for 24 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_ttHl_qq_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 35 inputs
# FlexiblePCAPreprocessor set up for 35 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_ttHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_ttHl_qq_ML/model_benchmark.txt
# --------------------------------------------
#  take D_ttHl_qq_ML from 180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/settings_training/D_ttHl_qq_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 64.0}
# building network with 35 inputs
# FlexiblePCAPreprocessor set up for 35 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/settings_training/D_WHl_qq_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_0.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_1.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_2.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_16.0number_layers_3.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_0.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_2.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_3.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_0.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_1.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_2.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_48.0number_layers_3.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_0.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_1.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_2.0/training/D_WHl_qq_ML/model_benchmark.txt
# attempting to load configuration file from /data_CMS/cms/wind/180516_hyperparameter_sweep/number_neurons_64.0number_layers_3.0/training/D_WHl_qq_ML/model_benchmark.txt
# --------------------------------------------
#  take D_WHl_qq_ML from 180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0
# --------------------------------------------
# attempting to load configuration file from /data_CMS/cms/wind/180515_hyperparameter_sweep/number_neurons_32.0number_layers_1.0/settings_training/D_WHl_qq_ML/settings.conf
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 32.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs

# %%
# now distriute again the training settings, as usual:
distribute_training_settings(os.path.join(campaign_workspace, output_run + '/'))
# Out:
# attempting to load configuration file from /data_CMS/cms/wind/180518_optimized_hyperparameters/optimized/settings.conf
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 11 inputs
# FlexiblePCAPreprocessor set up for 11 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 16.0}
# building network with 16 inputs
# FlexiblePCAPreprocessor set up for 16 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 48.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 48.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# got the following list of hyperparams: {u'number_layers': 3.0, u'number_neurons': 16.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 32.0}
# building network with 26 inputs
# FlexiblePCAPreprocessor set up for 26 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 64.0}
# building network with 25 inputs
# FlexiblePCAPreprocessor set up for 25 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 22 inputs
# FlexiblePCAPreprocessor set up for 22 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 64.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 48.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 32.0}
# building network with 36 inputs
# FlexiblePCAPreprocessor set up for 36 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 33 inputs
# FlexiblePCAPreprocessor set up for 33 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 34 inputs
# FlexiblePCAPreprocessor set up for 34 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 32.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 35 inputs
# FlexiblePCAPreprocessor set up for 35 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 16.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# got the following list of hyperparams: {u'number_layers': 3.0, u'number_neurons': 32.0}
# building network with 17 inputs
# FlexiblePCAPreprocessor set up for 17 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 16.0}
# building network with 26 inputs
# FlexiblePCAPreprocessor set up for 26 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 48.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 64.0}
# building network with 15 inputs
# FlexiblePCAPreprocessor set up for 15 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 64.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 48.0}
# building network with 36 inputs
# FlexiblePCAPreprocessor set up for 36 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 64.0}
# building network with 25 inputs
# FlexiblePCAPreprocessor set up for 25 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 32.0}
# building network with 33 inputs
# FlexiblePCAPreprocessor set up for 33 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 35 inputs
# FlexiblePCAPreprocessor set up for 35 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 32.0}
# building network with 38 inputs
# FlexiblePCAPreprocessor set up for 38 inputs
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# got the following list of hyperparams: {u'number_layers': 3.0, u'number_neurons': 64.0}
# building network with 24 inputs
# FlexiblePCAPreprocessor set up for 24 inputs
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 48.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 32.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 32.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 16.0}
# building network with 37 inputs
# FlexiblePCAPreprocessor set up for 37 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# got the following list of hyperparams: {u'number_layers': 3.0, u'number_neurons': 64.0}
# building network with 26 inputs
# FlexiblePCAPreprocessor set up for 26 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 48.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 64.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 32.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 42 inputs
# FlexiblePCAPreprocessor set up for 42 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 32.0}
# building network with 33 inputs
# FlexiblePCAPreprocessor set up for 33 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 16.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 48.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 35 inputs
# FlexiblePCAPreprocessor set up for 35 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 64.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 16.0}
# building network with 35 inputs
# FlexiblePCAPreprocessor set up for 35 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 48.0}
# building network with 36 inputs
# FlexiblePCAPreprocessor set up for 36 inputs
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 48.0}
# building network with 24 inputs
# FlexiblePCAPreprocessor set up for 24 inputs
# got the following list of hyperparams: {u'number_layers': 0.0, u'number_neurons': 64.0}
# building network with 35 inputs
# FlexiblePCAPreprocessor set up for 35 inputs
# got the following list of hyperparams: {u'number_layers': 1.0, u'number_neurons': 32.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
