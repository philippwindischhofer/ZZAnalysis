# %%
from bayes_opt import BayesianOptimization
import numpy as np
from sklearn.gaussian_process.kernels import Matern

import matplotlib.pyplot as plt
from matplotlib import gridspec
# %matplotlib inline

# plt.style.use(['dark_background'])

# %%
def xi_scheduler(iteration, max_iterations):
    return 0.001 + 0.19 * np.exp(-2 * iteration / max_iterations) + 0.01 * np.random.rand()

# %%
def posterior(bo, x):
    bo.gp.fit(bo.X, bo.Y)
    mu, sigma = bo.gp.predict(x, return_std=True)
    return mu, sigma

def plot_gp(bo, x):
    
    fig = plt.figure(figsize=(16, 10))
    fig.suptitle('Gaussian Process and Utility Function After {} Steps'.format(len(bo.X)), fontdict={'size':30})
    
    gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1]) 
    axis = plt.subplot(gs[0])
    acq = plt.subplot(gs[1])
    
    mu, sigma = posterior(bo, x)
    axis.plot(bo.X.flatten(), bo.Y, 'D', markersize=8, label=u'Observations', color='r')
    axis.plot(x, mu, '--', color='k', label='Prediction')

    axis.fill(np.concatenate([x, x[::-1]]), 
              np.concatenate([mu - 1.9600 * sigma, (mu + 1.9600 * sigma)[::-1]]),
        alpha=.6, fc='c', ec='None', label='95% confidence interval')
    
    axis.set_xlim((min(x), max(x)))
    axis.set_ylim((None, None))
    axis.set_ylabel('f(x)', fontdict={'size':20})
    axis.set_xlabel('x', fontdict={'size':20})
    
    utility = bo.util.utility(x, bo.gp, 0)
    acq.plot(x, utility, label='Utility Function', color='purple')
    acq.plot(x[np.argmax(utility)], np.max(utility), '*', markersize=15, 
             label=u'Next Best Guess', markerfacecolor='gold', markeredgecolor='k', markeredgewidth=1)
    acq.set_xlim((min(x), max(x)))
    acq.set_ylim((0, np.max(utility) + 0.5))
    acq.set_ylabel('Utility', fontdict={'size':20})
    acq.set_xlabel('x', fontdict={'size':20})
    
    axis.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)
    acq.legend(loc=2, bbox_to_anchor=(1.01, 1), borderaxespad=0.)

# %%
def target(x):
    return x * np.exp(-10000 * (x - 0.5)**2) - 5 + 0.1 * x

# %%
gp_params = {'kernel': 1.0 * Matern(length_scale = 0.01, length_scale_bounds = (1e-5, 1e5), nu = 1.5),
             'alpha':1e-4}

# %%
bo = BayesianOptimization(target, {'x': (0.2, 0.7)})

# %%
bo.maximize(init_points=2, n_iter=0, acq='poi', kappa=5, xi = xi_scheduler(0.0, 50), **gp_params)
plot_gp(bo, x)
# Out:
# Initialization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#     1 | 00m00s |   -4.97486 |    0.2514 |
#     2 | 00m00s |   -4.97562 |    0.2438 |
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |

# %%
for it in range(30):
    xi = xi_scheduler(it, 30)
    print "using xi = " + str(xi)
    bo.maximize(init_points=0, n_iter=1, acq='poi', kappa=5, xi = xi, **gp_params)
plot_gp(bo, x)
# Out:
# using xi = 0.191
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#     3 | 00m02s |   -4.93002 |    0.6998 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#     4 | 00m01s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#     5 | 00m01s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#     6 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#     7 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#     8 | 00m02s |   -4.98000 |    0.2000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#     9 | 00m01s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    10 | 00m01s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    11 | 00m01s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    12 | 00m02s |   -4.98000 |    0.2000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    13 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    14 | 00m01s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    15 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    16 | 00m01s |   -4.98000 |    0.2000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    17 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.0708970938226
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    18 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.026713703815
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    19 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.026713703815
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    20 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.026713703815
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    21 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.026713703815
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    22 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.026713703815
# Bayesian Optimization
# -----------------------------------------
#  Step |   Time |      Value |         x |
#    23 | 00m02s |   -4.93000 |    0.7000 |
# using xi = 0.026713703815

# %%
bo.res['max']
# Out:
# {'max_params': {'x': 0.49909125305405261, 'y': 0.50324720833222436},
#  'max_val': -4.4063175200736788}

# %%
plt.plot(x,y)
