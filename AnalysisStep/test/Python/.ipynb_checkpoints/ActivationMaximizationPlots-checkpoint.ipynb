# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from keras import backend as K
import os
import numpy as np
import uuid
import re
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt

# %%
import timeit

# %%
from trainlib.ModelCollection import ModelCollection
from trainlib.ModelCollectionConfigFileHandler import ModelCollectionConfigFileHandler
from trainlib.FileCollection import FileCollection
import trainlib.cuts as cuts
from trainlib.utils import read_data
# Out:
# Welcome to JupyROOT 6.10/09

# %%
confhandler = ModelCollectionConfigFileHandler()

# %%
run_dir = "/data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/"

# %%
confhandler.load_configuration(os.path.join(run_dir, "settings.conf"))
# Out:
# attempting to load configuration file from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/settings.conf

# %%
mcolls = confhandler.GetModelCollection(weightpath = os.path.join(run_dir, "training/"))
# Out:
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 10 inputs
# FlexiblePCAPreprocessor set up for 10 inputs
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 15 inputs
# FlexiblePCAPreprocessor set up for 15 inputs
# found the following models belonging to this collection:
# D_VBF_ggH_2j_ML
# D_VBF_ggH_0j_ML
# D_VBF_ggH_1j_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_2j_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_2j_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_2j_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_ggH_2j_ML_input': Index([       u'JetPt_2',          u'PFMET', u'D_VBF2j_ZHh_ME',
#        u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',        u'JetPt_1',   u'D_WHh_ggH_ME',
#          u'D_ZHh_ggH_ME',         u'Z1Mass',           u'Z2Pt',
#              u'JetEta_2',           u'ZZPt',   u'D_WHh_ZHh_ME',
#                 u'ZZEta',       u'JetEta_0',   u'JetPhi_2_sin',
#          u'JetPhi_2_cos',   u'JetPhi_0_sin',   u'JetPhi_0_cos',
#             u'ZZPhi_sin',      u'ZZPhi_cos',   u'JetPhi_1_sin',
#          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_ggH_2j_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_2j_ML/preprocessor.pkl
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_0j_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_0j_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_0j_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_ggH_0j_ML_input': Index([u'PFMET', u'Z2Mass', u'ZZPt', u'Z1Mass', u'Z1Pt', u'ZZMassErr',
#        u'ZZEta', u'Z2Pt', u'ZZPhi_sin', u'ZZPhi_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_ggH_0j_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_0j_ML/preprocessor.pkl
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_1j_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_1j_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_1j_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_ggH_1j_ML_input': Index([         u'PFMET',        u'JetPt_0',         u'Z2Mass',
#                  u'Z1Pt',      u'ZZMassErr',         u'Z1Mass',
#                  u'Z2Pt',           u'ZZPt', u'D_VBF1j_ggH_ME',
#                 u'ZZEta',       u'JetEta_0',   u'JetPhi_0_sin',
#          u'JetPhi_0_cos',      u'ZZPhi_sin',      u'ZZPhi_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_ggH_1j_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ggH_ML/D_VBF_ggH_1j_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# found the following models belonging to this collection:
# D_WHh_ggH_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_ggH_ML/D_WHh_ggH_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_ggH_ML/D_WHh_ggH_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_ggH_ML/D_WHh_ggH_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHh_ggH_ML_input': Index([       u'JetPt_2',          u'PFMET', u'D_VBF2j_ZHh_ME',
#        u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',        u'JetPt_1',   u'D_WHh_ggH_ME',
#          u'D_ZHh_ggH_ME',         u'Z1Mass',           u'Z2Pt',
#              u'JetEta_2',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_2_sin',   u'JetPhi_2_cos',   u'JetPhi_0_sin',
#          u'JetPhi_0_cos',      u'ZZPhi_sin',      u'ZZPhi_cos',
#          u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHh_ggH_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_ggH_ML/D_WHh_ggH_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 29 inputs
# FlexiblePCAPreprocessor set up for 29 inputs
# found the following models belonging to this collection:
# D_ZHh_ggH_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ggH_ML/D_ZHh_ggH_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ggH_ML/D_ZHh_ggH_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ggH_ML/D_ZHh_ggH_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ggH_ML_input': Index([                       u'JetPt_2',                          u'PFMET',
#                        u'D_VBF2j_WHh_ME',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                               u'JetPt_1',                       u'JetEta_2',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_2_sin',
#                          u'JetPhi_2_cos',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ggH_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ggH_ML/D_ZHh_ggH_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# found the following models belonging to this collection:
# D_WHh_ZHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_ZHh_ML/D_WHh_ZHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_ZHh_ML/D_WHh_ZHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_ZHh_ML/D_WHh_ZHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHh_ZHh_ML_input': Index([                       u'JetPt_2',                          u'PFMET',
#                        u'D_VBF2j_ZHh_ME',                 u'D_VBF2j_WHh_ME',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                   u'D_WHh_ggH_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                        u'JetPt_1',
#                              u'JetEta_2',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_2_sin',                   u'JetPhi_2_cos',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos',
#                          u'JetPhi_3_sin',                   u'JetPhi_3_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHh_ZHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_ZHh_ML/D_WHh_ZHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# found the following models belonging to this collection:
# D_VBF_WHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_WHh_ML/D_VBF_WHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_WHh_ML/D_VBF_WHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_WHh_ML/D_VBF_WHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_WHh_ML_input': Index([       u'JetPt_2',          u'PFMET', u'D_VBF2j_ZHh_ME',
#        u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',   u'D_WHh_ggH_ME',        u'JetPt_3',
#          u'D_ZHh_ggH_ME',         u'Z1Mass',           u'Z2Pt',
#               u'JetPt_1',       u'JetEta_2',           u'ZZPt',
#          u'D_WHh_ZHh_ME', u'D_VBF1j_ggH_ME',          u'ZZEta',
#              u'JetEta_0',   u'JetPhi_2_sin',   u'JetPhi_2_cos',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',   u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_WHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_WHh_ML/D_VBF_WHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# found the following models belonging to this collection:
# D_VBF_ZHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ZHh_ML/D_VBF_ZHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ZHh_ML/D_VBF_ZHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ZHh_ML/D_VBF_ZHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_ZHh_ML_input': Index([                       u'JetPt_2',                          u'PFMET',
#                        u'D_VBF2j_ZHh_ME',                 u'D_VBF2j_WHh_ME',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                   u'D_WHh_ggH_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                        u'JetPt_1',
#                              u'JetEta_2',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_2_sin',                   u'JetPhi_2_cos',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_ZHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_ZHh_ML/D_VBF_ZHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 19 inputs
# FlexiblePCAPreprocessor set up for 19 inputs
# found the following models belonging to this collection:
# D_WHl_ggH_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ggH_ML/D_WHl_ggH_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ggH_ML/D_WHl_ggH_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ggH_ML/D_WHl_ggH_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ggH_ML_input': Index([                 u'ZZMass_masked',                          u'PFMET',
#                          u'ExtraLepPt_0',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                         u'ExtraLepEta_0',                         u'Z1Mass',
#                                  u'Z2Pt',                           u'ZZPt',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ggH_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ggH_ML/D_WHl_ggH_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# found the following models belonging to this collection:
# D_WHl_VBF_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_VBF_ML/D_WHl_VBF_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_VBF_ML/D_WHl_VBF_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_VBF_ML/D_WHl_VBF_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_VBF_ML_input': Index([ u'ZZMass_masked',          u'PFMET',   u'ExtraLepPt_0',
#        u'D_VBF2j_ZHh_ME', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',  u'ExtraLepEta_0',   u'D_ZHh_ggH_ME',
#                u'Z1Mass',           u'Z2Pt',        u'JetPt_1',
#              u'JetEta_2',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',   u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_VBF_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_VBF_ML/D_WHl_VBF_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# found the following models belonging to this collection:
# D_WHl_WHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_WHh_ML/D_WHl_WHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_WHh_ML/D_WHl_WHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_WHh_ML/D_WHl_WHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_WHh_ML_input': Index([    u'ZZMass_masked',           u'JetPt_2',             u'PFMET',
#             u'ExtraLepPt_0',    u'D_VBF2j_WHh_ME',    u'D_VBF2j_ggH_ME',
#                  u'JetPt_0',            u'Z2Mass',          u'JetEta_1',
#                     u'Z1Pt',         u'ZZMassErr',      u'D_WHh_ggH_ME',
#            u'ExtraLepEta_0',      u'D_ZHh_ggH_ME',            u'Z1Mass',
#                     u'Z2Pt',           u'JetPt_1',              u'ZZPt',
#             u'D_WHh_ZHh_ME',    u'D_VBF1j_ggH_ME',             u'ZZEta',
#                 u'JetEta_0',      u'JetPhi_0_sin',      u'JetPhi_0_cos',
#                u'ZZPhi_sin',         u'ZZPhi_cos',      u'JetPhi_1_sin',
#             u'JetPhi_1_cos', u'ExtraLepPhi_0_sin', u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_WHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_WHh_ML/D_WHl_WHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 26 inputs
# FlexiblePCAPreprocessor set up for 26 inputs
# found the following models belonging to this collection:
# D_WHl_ZHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHh_ML/D_WHl_ZHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHh_ML/D_WHl_ZHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHh_ML/D_WHl_ZHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ZHh_ML_input': Index([                 u'ZZMass_masked',                      u'nExtraLep',
#                                 u'PFMET',                   u'ExtraLepPt_0',
#                        u'D_VBF2j_WHh_ME',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                  u'ExtraLepEta_0',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                        u'JetPt_1',
#                                  u'ZZPt',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                     u'ExtraLepPhi_0_sin',              u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ZHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHh_ML/D_WHl_ZHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 25 inputs
# FlexiblePCAPreprocessor set up for 25 inputs
# found the following models belonging to this collection:
# D_WHl_ZHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHl_ML/D_WHl_ZHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHl_ML/D_WHl_ZHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHl_ML/D_WHl_ZHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ZHl_ML_input': Index([    u'ZZMass_masked',         u'nExtraLep',             u'PFMET',
#             u'ExtraLepPt_0',           u'JetPt_0',            u'Z2Mass',
#                 u'JetEta_1',              u'Z1Pt',         u'ZZMassErr',
#            u'ExtraLepEta_0',      u'D_ZHh_ggH_ME',            u'Z1Mass',
#                     u'Z2Pt',              u'ZZPt',    u'D_VBF1j_ggH_ME',
#                    u'ZZEta',          u'JetEta_0',      u'JetPhi_0_sin',
#             u'JetPhi_0_cos',         u'ZZPhi_sin',         u'ZZPhi_cos',
#             u'JetPhi_1_sin',      u'JetPhi_1_cos', u'ExtraLepPhi_0_sin',
#        u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ZHl_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHl_ML/D_WHl_ZHl_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 23 inputs
# FlexiblePCAPreprocessor set up for 23 inputs
# found the following models belonging to this collection:
# D_WHl_ZHMET_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHMET_ML/D_WHl_ZHMET_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHMET_ML/D_WHl_ZHMET_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHMET_ML/D_WHl_ZHMET_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ZHMET_ML_input': Index([    u'ZZMass_masked',         u'nExtraLep',             u'PFMET',
#             u'ExtraLepPt_0',           u'JetPt_0',            u'Z2Mass',
#                     u'Z1Pt',         u'ZZMassErr',     u'ExtraLepEta_0',
#                   u'Z1Mass',              u'Z2Pt',              u'ZZPt',
#           u'D_VBF1j_ggH_ME',             u'ZZEta',          u'JetEta_0',
#             u'JetPhi_0_sin',      u'JetPhi_0_cos',         u'ZZPhi_sin',
#                u'ZZPhi_cos',      u'JetPhi_1_sin',      u'JetPhi_1_cos',
#        u'ExtraLepPhi_1_sin', u'ExtraLepPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ZHMET_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ZHMET_ML/D_WHl_ZHMET_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 33 inputs
# FlexiblePCAPreprocessor set up for 33 inputs
# found the following models belonging to this collection:
# D_WHl_ttHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHh_ML/D_WHl_ttHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHh_ML/D_WHl_ttHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHh_ML/D_WHl_ttHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ttHh_ML_input': Index([                 u'ZZMass_masked',                        u'JetPt_2',
#                                 u'PFMET',                   u'ExtraLepPt_0',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#                      u'nCleanedJetsPt30', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                        u'JetPt_3',
#                         u'ExtraLepEta_0',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                               u'JetPt_1',                       u'JetEta_2',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_2_sin',
#                          u'JetPhi_2_cos',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ttHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHh_ML/D_WHl_ttHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 34 inputs
# FlexiblePCAPreprocessor set up for 34 inputs
# found the following models belonging to this collection:
# D_WHl_ttHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHl_ML/D_WHl_ttHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHl_ML/D_WHl_ttHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHl_ML/D_WHl_ttHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_ttHl_ML_input': Index([                 u'ZZMass_masked',                      u'nExtraLep',
#                               u'JetPt_2',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0',               u'nCleanedJetsPt30',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                        u'JetPt_1',
#                          u'D_WHh_ggH_ME',                        u'JetPt_3',
#                         u'ExtraLepEta_0',                   u'ExtraLepPt_1',
#                                u'Z1Mass',                           u'Z2Pt',
#                          u'D_ZHh_ggH_ME',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos',
#                     u'ExtraLepPhi_0_sin',              u'ExtraLepPhi_0_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_ttHl_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_ttHl_ML/D_WHl_ttHl_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 23 inputs
# FlexiblePCAPreprocessor set up for 23 inputs
# found the following models belonging to this collection:
# D_ZHh_ZHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHl_ML/D_ZHh_ZHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHl_ML/D_ZHh_ZHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHl_ML/D_ZHh_ZHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ZHl_ML_input': Index([                 u'ZZMass_masked',                          u'PFMET',
#                          u'ExtraLepPt_0',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ZHl_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHl_ML/D_ZHh_ZHl_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 26 inputs
# FlexiblePCAPreprocessor set up for 26 inputs
# found the following models belonging to this collection:
# D_ZHh_ZHMET_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHMET_ML/D_ZHh_ZHMET_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHMET_ML/D_ZHh_ZHMET_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHMET_ML/D_ZHh_ZHMET_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ZHMET_ML_input': Index([                       u'JetPt_2',                          u'PFMET',
#                        u'D_VBF2j_ZHh_ME',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                               u'JetPt_1',                   u'D_WHh_ggH_ME',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ZHMET_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ZHMET_ML/D_ZHh_ZHMET_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# found the following models belonging to this collection:
# D_ZHh_ttHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHh_ML/D_ZHh_ttHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHh_ML/D_ZHh_ttHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHh_ML/D_ZHh_ttHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ttHh_ML_input': Index([                 u'ZZMass_masked',                      u'nExtraLep',
#                               u'JetPt_2',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ZHh_ME',
#                        u'D_VBF2j_WHh_ME',                        u'JetPt_0',
#                      u'nCleanedJetsPt30', u'nCleanedJetsPt30BTagged_bTagSF',
#                              u'JetEta_3',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                               u'JetPt_1',                   u'D_WHh_ggH_ME',
#                               u'JetPt_3',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                              u'JetEta_2',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos',
#                     u'ExtraLepPhi_0_sin',              u'ExtraLepPhi_0_cos',
#                          u'JetPhi_3_sin',                   u'JetPhi_3_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ttHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHh_ML/D_ZHh_ttHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 36 inputs
# FlexiblePCAPreprocessor set up for 36 inputs
# found the following models belonging to this collection:
# D_ZHh_ttHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHl_ML/D_ZHh_ttHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHl_ML/D_ZHh_ttHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHl_ML/D_ZHh_ttHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_ttHl_ML_input': Index([                 u'ZZMass_masked',                      u'nExtraLep',
#                               u'JetPt_2',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ZHh_ME',
#                        u'D_VBF2j_WHh_ME',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0',               u'nCleanedJetsPt30',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                        u'JetPt_1',
#                          u'D_WHh_ggH_ME',                        u'JetPt_3',
#                         u'ExtraLepEta_0',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                              u'JetEta_2',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_2_sin',                   u'JetPhi_2_cos',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_ttHl_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_ttHl_ML/D_ZHh_ttHl_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 24 inputs
# FlexiblePCAPreprocessor set up for 24 inputs
# found the following models belonging to this collection:
# D_ZHl_ggH_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ggH_ML/D_ZHl_ggH_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ggH_ML/D_ZHl_ggH_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ggH_ML/D_ZHl_ggH_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_ggH_ML_input': Index([ u'ZZMass_masked',          u'PFMET',   u'ExtraLepPt_0',
#        u'D_VBF2j_ggH_ME',        u'JetPt_0',         u'Z2Mass',
#              u'JetEta_1',           u'Z1Pt',      u'ZZMassErr',
#          u'D_ZHh_ggH_ME',         u'Z1Mass',           u'Z2Pt',
#               u'JetPt_1',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',   u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_ggH_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ggH_ML/D_ZHl_ggH_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 27 inputs
# FlexiblePCAPreprocessor set up for 27 inputs
# found the following models belonging to this collection:
# D_ZHl_VBF_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_VBF_ML/D_ZHl_VBF_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_VBF_ML/D_ZHl_VBF_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_VBF_ML/D_ZHl_VBF_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_VBF_ML_input': Index([ u'ZZMass_masked',          u'PFMET',   u'ExtraLepPt_0',
#        u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',        u'JetPt_1',  u'ExtraLepEta_0',
#          u'D_ZHh_ggH_ME',         u'Z1Mass',           u'Z2Pt',
#              u'JetEta_2',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',   u'JetPhi_1_sin',   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_VBF_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_VBF_ML/D_ZHl_VBF_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# found the following models belonging to this collection:
# D_ZHl_WHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_WHh_ML/D_ZHl_WHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_WHh_ML/D_ZHl_WHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_WHh_ML/D_ZHl_WHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_WHh_ML_input': Index([                 u'ZZMass_masked',                          u'PFMET',
#                          u'ExtraLepPt_0',                 u'D_VBF2j_ggH_ME',
#                               u'JetPt_0', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                           u'Z2Pt',
#                               u'JetPt_1',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                 u'D_VBF1j_ggH_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_2_sin',                   u'JetPhi_2_cos',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_WHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_WHh_ML/D_ZHl_WHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 22 inputs
# FlexiblePCAPreprocessor set up for 22 inputs
# found the following models belonging to this collection:
# D_ZHl_ZHMET_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ZHMET_ML/D_ZHl_ZHMET_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ZHMET_ML/D_ZHl_ZHMET_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ZHMET_ML/D_ZHl_ZHMET_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_ZHMET_ML_input': Index([ u'ZZMass_masked',      u'nExtraLep',          u'PFMET',
#          u'ExtraLepPt_0', u'D_VBF2j_WHh_ME', u'D_VBF2j_ggH_ME',
#               u'JetPt_0',         u'Z2Mass',           u'Z1Pt',
#             u'ZZMassErr',   u'D_ZHh_ggH_ME',         u'Z1Mass',
#                  u'Z2Pt',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_ZHMET_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ZHMET_ML/D_ZHl_ZHMET_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# found the following models belonging to this collection:
# D_ZHl_ttHh_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHh_ML/D_ZHl_ttHh_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHh_ML/D_ZHl_ttHh_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHh_ML/D_ZHl_ttHh_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_ttHh_ML_input': Index([                 u'ZZMass_masked',                        u'JetPt_2',
#                                 u'PFMET',                   u'ExtraLepPt_0',
#                               u'JetPt_0', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                               u'JetPt_1',                   u'D_WHh_ggH_ME',
#                               u'JetPt_3',                  u'ExtraLepEta_0',
#                          u'D_ZHh_ggH_ME',                         u'Z1Mass',
#                                  u'Z2Pt',                       u'JetEta_2',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                          u'JetPhi_2_sin',                   u'JetPhi_2_cos',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                          u'JetPhi_1_sin',                   u'JetPhi_1_cos',
#                          u'JetPhi_3_sin',                   u'JetPhi_3_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_ttHh_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHh_ML/D_ZHl_ttHh_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 32 inputs
# FlexiblePCAPreprocessor set up for 32 inputs
# found the following models belonging to this collection:
# D_ZHl_ttHl_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHl_ML/D_ZHl_ttHl_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHl_ML/D_ZHl_ttHl_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_ttHl_ML/D_ZHl_ttHl_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_ttHl_ML_input': Index([                 u'ZZMass_masked',                      u'nExtraLep',
# ...
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_bkg_ML/D_VBF_bkg_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_VBF_bkg_ML_input': Index([         u'PFMET', u'D_VBF2j_ggH_ME',        u'JetPt_0',
#                u'Z2Mass',       u'JetEta_1',           u'Z1Pt',
#             u'ZZMassErr',       u'D_bkg_ME',         u'Z1Mass',
#          u'costhetastar',           u'Z2Pt',         u'Z2Flav',
#         u'helcosthetaZ2',  u'helcosthetaZ1',           u'ZZPt',
#          u'D_WHh_ZHh_ME', u'D_VBF1j_ggH_ME',          u'ZZEta',
#              u'JetEta_0',  u'phistarZ1_sin',  u'phistarZ1_cos',
#          u'JetPhi_0_sin',   u'JetPhi_0_cos',      u'ZZPhi_sin',
#             u'ZZPhi_cos',     u'helphi_sin',     u'helphi_cos',
#            u'xistar_sin',     u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_VBF_bkg_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_VBF_bkg_ML/D_VBF_bkg_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# found the following models belonging to this collection:
# D_ZHh_bkg_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_bkg_ML/D_ZHh_bkg_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_bkg_ML/D_ZHh_bkg_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_bkg_ML/D_ZHh_bkg_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHh_bkg_ML_input': Index([ u'ZZMass_masked',          u'PFMET', u'D_VBF2j_ggH_ME',
#               u'JetPt_0',         u'Z2Mass',           u'Z1Pt',
#             u'ZZMassErr',   u'D_WHh_ggH_ME',       u'D_bkg_ME',
#          u'D_ZHh_ggH_ME',         u'Z1Mass',   u'costhetastar',
#                  u'Z2Pt',         u'Z2Flav',  u'helcosthetaZ2',
#         u'helcosthetaZ1',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#         u'phistarZ1_sin',  u'phistarZ1_cos',   u'JetPhi_0_sin',
#          u'JetPhi_0_cos',      u'ZZPhi_sin',      u'ZZPhi_cos',
#            u'helphi_sin',     u'helphi_cos',     u'xistar_sin',
#            u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHh_bkg_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHh_bkg_ML/D_ZHh_bkg_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 33 inputs
# FlexiblePCAPreprocessor set up for 33 inputs
# found the following models belonging to this collection:
# D_ZHl_bkg_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_bkg_ML/D_ZHl_bkg_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_bkg_ML/D_ZHl_bkg_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_bkg_ML/D_ZHl_bkg_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHl_bkg_ML_input': Index([ u'ZZMass_masked',          u'PFMET',   u'ExtraLepPt_0',
#        u'D_VBF2j_ggH_ME',        u'JetPt_0',         u'Z2Mass',
#              u'JetEta_1',           u'Z1Pt',      u'ZZMassErr',
#          u'D_WHh_ggH_ME',       u'D_bkg_ME',         u'Z1Mass',
#          u'costhetastar',           u'Z2Pt',         u'Z2Flav',
#         u'helcosthetaZ2',  u'helcosthetaZ1',           u'ZZPt',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#         u'phistarZ1_sin',  u'phistarZ1_cos',   u'JetPhi_0_sin',
#          u'JetPhi_0_cos',      u'ZZPhi_sin',      u'ZZPhi_cos',
#            u'helphi_sin',     u'helphi_cos',   u'JetPhi_1_sin',
#          u'JetPhi_1_cos',     u'xistar_sin',     u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHl_bkg_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHl_bkg_ML/D_ZHl_bkg_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 31 inputs
# FlexiblePCAPreprocessor set up for 31 inputs
# found the following models belonging to this collection:
# D_WHh_bkg_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_bkg_ML/D_WHh_bkg_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_bkg_ML/D_WHh_bkg_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_bkg_ML/D_WHh_bkg_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHh_bkg_ML_input': Index([ u'ZZMass_masked',          u'PFMET', u'D_VBF2j_ggH_ME',
#               u'JetPt_0',         u'Z2Mass',           u'Z1Pt',
#             u'ZZMassErr',   u'D_WHh_ggH_ME',       u'D_bkg_ME',
#                u'Z1Mass',   u'costhetastar',           u'Z2Pt',
#                u'Z2Flav',        u'JetPt_1',  u'helcosthetaZ2',
#         u'helcosthetaZ1',           u'ZZPt',   u'D_WHh_ZHh_ME',
#        u'D_VBF1j_ggH_ME',          u'ZZEta',       u'JetEta_0',
#         u'phistarZ1_sin',  u'phistarZ1_cos',   u'JetPhi_0_sin',
#          u'JetPhi_0_cos',      u'ZZPhi_sin',      u'ZZPhi_cos',
#            u'helphi_sin',     u'helphi_cos',     u'xistar_sin',
#            u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHh_bkg_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHh_bkg_ML/D_WHh_bkg_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 28 inputs
# FlexiblePCAPreprocessor set up for 28 inputs
# found the following models belonging to this collection:
# D_WHl_bkg_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_bkg_ML/D_WHl_bkg_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_bkg_ML/D_WHl_bkg_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_bkg_ML/D_WHl_bkg_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_WHl_bkg_ML_input': Index([u'ZZMass_masked',         u'PFMET',  u'ExtraLepPt_0',       u'JetPt_0',
#               u'Z2Mass',          u'Z1Pt',     u'ZZMassErr',      u'D_bkg_ME',
#               u'Z1Mass',  u'costhetastar',          u'Z2Pt',        u'Z2Flav',
#        u'helcosthetaZ2', u'helcosthetaZ1',          u'ZZPt',  u'D_WHh_ZHh_ME',
#                u'ZZEta',      u'JetEta_0', u'phistarZ1_sin', u'phistarZ1_cos',
#         u'JetPhi_0_sin',  u'JetPhi_0_cos',     u'ZZPhi_sin',     u'ZZPhi_cos',
#           u'helphi_sin',    u'helphi_cos',    u'xistar_sin',    u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_WHl_bkg_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_WHl_bkg_ML/D_WHl_bkg_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 30 inputs
# FlexiblePCAPreprocessor set up for 30 inputs
# found the following models belonging to this collection:
# D_ZHMET_bkg_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHMET_bkg_ML/D_ZHMET_bkg_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHMET_bkg_ML/D_ZHMET_bkg_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHMET_bkg_ML/D_ZHMET_bkg_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ZHMET_bkg_ML_input': Index([                 u'ZZMass_masked',                          u'PFMET',
#                                u'Z1Flav',                 u'D_VBF2j_WHh_ME',
#                               u'JetPt_0', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                           u'Z1Pt',
#                             u'ZZMassErr',                       u'D_bkg_ME',
#                                u'Z1Mass',                   u'costhetastar',
#                                  u'Z2Pt',                         u'Z2Flav',
#                         u'helcosthetaZ2',                  u'helcosthetaZ1',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                                 u'ZZEta',                       u'JetEta_0',
#                         u'phistarZ1_sin',                  u'phistarZ1_cos',
#                          u'JetPhi_0_sin',                   u'JetPhi_0_cos',
#                             u'ZZPhi_sin',                      u'ZZPhi_cos',
#                            u'helphi_sin',                     u'helphi_cos',
#                            u'xistar_sin',                     u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ZHMET_bkg_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ZHMET_bkg_ML/D_ZHMET_bkg_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 41 inputs
# FlexiblePCAPreprocessor set up for 41 inputs
# found the following models belonging to this collection:
# D_ttHh_bkg_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ttHh_bkg_ML/D_ttHh_bkg_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ttHh_bkg_ML/D_ttHh_bkg_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ttHh_bkg_ML/D_ttHh_bkg_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ttHh_bkg_ML_input': Index([                 u'ZZMass_masked',                        u'JetPt_2',
#                                 u'PFMET',                 u'D_VBF2j_WHh_ME',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#                      u'nCleanedJetsPt30', u'nCleanedJetsPt30BTagged_bTagSF',
#                                u'Z2Mass',                       u'JetEta_1',
#                                  u'Z1Pt',                      u'ZZMassErr',
#                          u'D_WHh_ggH_ME',                        u'JetPt_3',
#                              u'D_bkg_ME',                   u'D_ZHh_ggH_ME',
#                                u'Z1Mass',                   u'costhetastar',
#                                  u'Z2Pt',                         u'Z2Flav',
#                               u'JetPt_1',                  u'helcosthetaZ2',
#                         u'helcosthetaZ1',                           u'ZZPt',
#                          u'D_WHh_ZHh_ME',                          u'ZZEta',
#                              u'JetEta_0',                   u'JetPhi_2_sin',
#                          u'JetPhi_2_cos',                  u'phistarZ1_sin',
#                         u'phistarZ1_cos',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                     u'helphi_sin',
#                            u'helphi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos',                     u'xistar_sin',
#                            u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ttHh_bkg_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ttHh_bkg_ML/D_ttHh_bkg_ML/preprocessor.pkl
# got the following list of hyperparams: {u'number_layers': 2.0, u'number_neurons': 64.0}
# building network with 37 inputs
# FlexiblePCAPreprocessor set up for 37 inputs
# found the following models belonging to this collection:
# D_ttHl_bkg_ML
# now attempting to load model from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ttHl_bkg_ML/D_ttHl_bkg_ML/final.hdf5
# read weights from /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ttHl_bkg_ML/D_ttHl_bkg_ML/final.hdf5
# now attempting to load column settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ttHl_bkg_ML/D_ttHl_bkg_ML/processed_columns_preprocessor.pkl
# PCA setup for 'D_ttHl_bkg_ML_input': Index([                 u'ZZMass_masked',                        u'JetPt_2',
#                                 u'PFMET',                   u'ExtraLepPt_0',
#                        u'D_VBF2j_ggH_ME',                        u'JetPt_0',
#        u'nCleanedJetsPt30BTagged_bTagSF',                         u'Z2Mass',
#                              u'JetEta_1',                           u'Z1Pt',
#                             u'ZZMassErr',                        u'JetPt_1',
#                          u'D_WHh_ggH_ME',                       u'D_bkg_ME',
#                                u'Z1Mass',                   u'costhetastar',
#                                  u'Z2Pt',                         u'Z2Flav',
#                         u'helcosthetaZ2',                  u'helcosthetaZ1',
#                                  u'ZZPt',                   u'D_WHh_ZHh_ME',
#                        u'D_VBF1j_ggH_ME',                          u'ZZEta',
#                              u'JetEta_0',                  u'phistarZ1_sin',
#                         u'phistarZ1_cos',                   u'JetPhi_0_sin',
#                          u'JetPhi_0_cos',                      u'ZZPhi_sin',
#                             u'ZZPhi_cos',                     u'helphi_sin',
#                            u'helphi_cos',                   u'JetPhi_1_sin',
#                          u'JetPhi_1_cos',                     u'xistar_sin',
#                            u'xistar_cos'],
#       dtype='object')
# PCAWhiteningPreprocessor for stream 'D_ttHl_bkg_ML_input'
# now attempting to load preprocessor settings from file /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/training/D_ttHl_bkg_ML/D_ttHl_bkg_ML/preprocessor.pkl
# 2018-05-09 18:01:22.818665: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2018-05-09 18:01:22.818705: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2018-05-09 18:01:22.818713: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.

# %%
network_name = "D_VBF_WHh_ML"

# %%
fixed_input = {"nCleanedJetsPt30": 2}

# %%
# find the desired neural network, as given by its name; and hold on to the network itself and its preprocessor

# %%
for mcoll in mcolls:
    if network_name in mcoll.model_dict.keys():
        found_mcoll = mcoll
        model = mcoll.model_dict[network_name]
        pre = mcoll.preprocessor_dict[network_name]
        break

# %%
# the actual names of the dataframe columns
column_names = list(set(map(lambda x: re.sub('\[.*\]', '', x), pre.periodic_columns + pre.nonperiodic_columns)))

# %%
column_names
# Out:
# [u'D_VBF1j_ggH_ME',
#  u'ZZPt',
#  u'ZZPhi',
#  u'PFMET',
#  u'ZZEta',
#  u'JetPt',
#  u'JetPhi',
#  u'D_ZHh_ggH_ME',
#  u'Z2Mass',
#  u'D_VBF2j_ZHh_ME',
#  u'D_VBF2j_WHh_ME',
#  u'Z1Mass',
#  u'D_WHh_ZHh_ME',
#  u'Z1Pt',
#  u'ZZMassErr',
#  u'JetEta',
#  u'D_VBF2j_ggH_ME',
#  u'Z2Pt',
#  u'D_WHh_ggH_ME']

# %%
# synthesize a Pandas frame with the inputs this network expects

# %%
variable_ranges = {
    "JetPt": (30, 500.0),
    "JetEta": (-2, 2),
    "JetPhi": (-np.pi, np.pi),
    "ZZPt": (15, 200.0),
    "ZZPhi": (-np.pi, np.pi),
    "PFMET": (20, 50.0),
    "ZZEta": (-3.0, 3.0),
    "Z2Mass": (12, 60),
    "Z1Mass": (40, 110),
    "ZZMassErr": (0, 6),
    "Z1Pt": (30, 300),
    "Z2Pt": (30, 200),
    "D_ZHh_ggH_ME": (0.0, 1e-3),
    "D_VBF2j_ZHh_ME": (0.9, 1.0),
    "D_VBF2j_WHh_ME": (0.9, 1.0),
    "D_WHh_ZHh_ME": (0.9, 1.0),
    "D_VBF2j_ggH_ME": (0.9, 1.0),
    "D_WHh_ggH_ME": (0.0, 1e-3),
    "D_VBF1j_ggH_ME": (0.0, 1e-3)
}

# %%
# to test it with real data:
fcoll = FileCollection({"/data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/augmentation_test/VBFH125/ZZ4lAnalysis.root" : cuts.no_cut}, 0.0, 1.0)
setup_data = read_data(fcoll, 0, 200, branches = ["nCleanedJetsPt30", "D_VBF_ggH_ML"] + variable_ranges.keys())
# Out:
# skimming /data_CMS/cms/wind/180508_bkg_cat_ZXonly/number_layers_2.0_number_neurons_64.0/augmentation_test/VBFH125/ZZ4lAnalysis.root
# collection set up: 1 files, 15580 entries in total, 15580 of which will be used

# %%
real_data = setup_data.loc[setup_data["nCleanedJetsPt30"] == 2]

# %%
pre_data = pre.process(setup_data)

# %%
model.get_keras_model().predict(x = pre_data, verbose = 0, batch_size = len(pre_data))
# Out:
# array([[ 0.99972862],
#        [ 0.12409092],
#        [ 0.65592301],
#        [ 0.97142237],
#        [ 0.61278617],
#        [ 0.11177555],
#        [ 0.59716117],
#        [ 0.17678708],
#        [ 0.54452103],
#        [ 0.99405485],
#        [ 0.93300295],
#        [ 0.74415523],
#        [ 0.61511642],
#        [ 0.53617573],
#        [ 0.62764621],
#        [ 0.48626071],
#        [ 0.95219874],
#        [ 0.90797985],
#        [ 0.98171598],
#        [ 0.98418343],
#        [ 0.13523753],
#        [ 0.47210717],
#        [ 0.95570719],
#        [ 0.58366758],
#        [ 0.56989419],
#        [ 0.86993271],
#        [ 0.6249392 ],
#        [ 0.98514754],
#        [ 0.931481  ],
#        [ 0.94433063],
#        [ 0.7301361 ],
#        [ 0.70081764],
#        [ 0.14464642],
#        [ 0.98201638],
#        [ 0.98995948],
#        [ 0.99110729],
#        [ 0.98706114],
#        [ 0.95508707],
#        [ 0.69862849],
#        [ 0.62498283],
#        [ 0.69970798],
#        [ 0.51529479],
#        [ 0.85211432],
#        [ 0.99691522],
#        [ 0.99861109],
#        [ 0.98905087],
#        [ 0.99723464],
#        [ 0.98963016],
#        [ 0.89466649],
#        [ 0.99509722],
#        [ 0.55403066],
#        [ 0.86223727],
#        [ 0.42867172],
#        [ 0.1487527 ],
#        [ 0.38184285],
#        [ 0.86346513],
#        [ 0.48921734],
#        [ 0.74234736],
#        [ 0.17276593],
#        [ 0.99739528],
#        [ 0.85936779],
#        [ 0.98956609],
#        [ 0.5462051 ],
#        [ 0.80153215],
#        [ 0.94545656],
#        [ 0.0652071 ],
#        [ 0.99727935],
#        [ 0.87016898],
#        [ 0.82775855],
#        [ 0.58013588],
#        [ 0.93284172],
#        [ 0.99783915],
#        [ 0.17491028],
#        [ 0.44098216],
#        [ 0.99445045],
#        [ 0.99960929],
#        [ 0.57670927],
#        [ 0.8448661 ],
#        [ 0.97502589],
#        [ 0.54702199],
#        [ 0.83459336],
#        [ 0.85798812],
#        [ 0.99723899],
#        [ 0.75750285],
#        [ 0.99460077],
#        [ 0.26421791],
#        [ 0.38601592],
#        [ 0.19179077],
#        [ 0.57394046],
#        [ 0.83030897],
#        [ 0.33652535],
#        [ 0.53196728],
#        [ 0.68455899],
#        [ 0.9886362 ],
#        [ 0.33640665],
#        [ 0.542198  ],
#        [ 0.39481923],
#        [ 0.99773669],
#        [ 0.29673806],
#        [ 0.56529176],
#        [ 0.89065111],
#        [ 0.97150856],
#        [ 0.99149621],
#        [ 0.44359216],
#        [ 0.16585451],
#        [ 0.81556535],
#        [ 0.98160166],
#        [ 0.94100767],
#        [ 0.64925158],
#        [ 0.84252822],
#        [ 0.83241725],
#        [ 0.59582323],
#        [ 0.22450505],
#        [ 0.94228506],
#        [ 0.56023479],
#        [ 0.98889446],
#        [ 0.57939053],
#        [ 0.14066248],
#        [ 0.97495031],
#        [ 0.98796076],
#        [ 0.98179227],
#        [ 0.95806825],
#        [ 0.99943894],
#        [ 0.99552345],
#        [ 0.99274135],
#        [ 0.75825447],
#        [ 0.92167497],
#        [ 0.21226895],
#        [ 0.99830878],
#        [ 0.35590589],
#        [ 0.34844184],
#        [ 0.97929472],
#        [ 0.98922473],
#        [ 0.98357242],
#        [ 0.30299062],
#        [ 0.96235114],
#        [ 0.97573984],
#        [ 0.99706846],
#        [ 0.76434928],
#        [ 0.99211603],
#        [ 0.14726731],
#        [ 0.93888187],
#        [ 0.16586326],
#        [ 0.93995893],
#        [ 0.99687248],
#        [ 0.8315413 ],
#        [ 0.99926561],
#        [ 0.84853411],
#        [ 0.87504697],
#        [ 0.99534059],
#        [ 0.90064245],
#        [ 0.51641005],
#        [ 0.96083891],
#        [ 0.92285663],
#        [ 0.17342693],
#        [ 0.99791723],
#        [ 0.89340574],
#        [ 0.87996972],
#        [ 0.61151671],
#        [ 0.92245924],
#        [ 0.55566204],
#        [ 0.14102654],
#        [ 0.39666358],
#        [ 0.99924999],
#        [ 0.97203189],
#        [ 0.95373756],
#        [ 0.38094217],
#        [ 0.9990595 ],
#        [ 0.46324545],
#        [ 0.88094735],
#        [ 0.99465102],
#        [ 0.57525432],
#        [ 0.9628858 ],
#        [ 0.97647059],
#        [ 0.99944812],
#        [ 0.98163658],
#        [ 0.98563749],
#        [ 0.92392278],
#        [ 0.88590699],
#        [ 0.72205114],
#        [ 0.59293884],
#        [ 0.89151663],
#        [ 0.40445212],
#        [ 0.4287217 ],
#        [ 0.99804401],
#        [ 0.98995811],
#        [ 0.98647004],
#        [ 0.95432097],
#        [ 0.97942221],
#        [ 0.94800735],
#        [ 0.64281923],
#        [ 0.53662741],
#        [ 0.99646521],
#        [ 0.71312255],
#        [ 0.56790578],
#        [ 0.93969303],
#        [ 0.9654308 ],
#        [ 0.99734938],
#        [ 0.95699561],
#        [ 0.99413151]], dtype=float32)

# %%
setup_data
# Out:
#      nCleanedJetsPt30  D_VBF_ggH_ML  D_VBF1j_ggH_ME  D_VBF2j_WHh_ME     ZZPhi  \
# 0                   2      0.932677        0.000000        1.000000 -1.949017
# 1                   1      0.792358        0.002723        0.000000 -2.488447
# 2                   0      0.994909        0.000000        0.000000 -1.288448
# 3                   3      0.843389        0.000000        0.999894 -1.576967
# 4                   0      0.715976        0.000000        0.000000 -2.452845
# 5                   3      0.370441        0.000000        0.790154 -3.039008
# 6                   0      0.653664        0.000000        0.000000 -1.271718
# 7                   1      0.375750        0.693744        0.000000 -3.037029
# 8                   1      0.596975        0.218736        0.000000 -1.629294
# 9                   2      0.813968        0.000000        0.999524 -1.684583
# 10                  1      0.579332        0.834740        0.000000  1.822647
# 11                  1      0.514807        0.194523        0.000000 -0.170062
# 12                  0      0.552862        0.000000        0.000000 -2.372477
# 13                  0      0.271675        0.000000        0.000000  3.108213
# 14                  0      0.986992        0.000000        0.000000 -2.979199
# 15                  1      0.477806        0.533842        0.000000 -0.339915
# 16                  1      0.724196        0.342123        0.000000 -0.291012
# 17                  1      0.575840        0.258384        0.000000  2.998635
# 18                  2      0.828368        0.000000        0.999542  2.660143
# 19                  2      0.957949        0.000000        0.999768 -0.170687
# 20                  1      0.280240        0.422620        0.000000 -1.296608
# 21                  4      0.593404        0.000000        0.999059 -2.877672
# 22                  1      0.708465        0.897807        0.000000  2.200773
# 23                  0      0.838168        0.000000        0.000000 -1.115956
# 24                  0      0.338713        0.000000        0.000000  0.886636
# 25                  1      0.432404        0.621441        0.000000 -0.595480
# 26                  0      0.913374        0.000000        0.000000 -0.331735
# 27                  3      0.656093        0.000000        0.999957 -2.696398
# 28                  2      0.829547        0.000000        0.992193  1.794589
# 29                  2      0.932225        0.000000        0.994731  0.968232
# ..                ...           ...             ...             ...       ...
# 170                 2      0.955643        0.000000        0.999969 -2.408156
# 171                 0      0.536584        0.000000        0.000000 -0.485852
# 172                 1      0.718668        0.866342        0.000000 -0.697970
# 173                 1      0.935934        0.627311        0.000000  0.581047
# 174                 2      0.941851        0.000000        1.000000 -0.242392
# 175                 2      0.776133        0.000000        0.999155  0.799617
# 176                 2      0.841696        0.000000        0.998032  0.990557
# 177                 1      0.425562        0.340714        0.000000 -1.741180
# 178                 1      0.737917        0.509220        0.000000 -0.713124
# 179                 2      0.426060        0.000000        0.008558 -2.304321
# 180                 0      0.449872        0.000000        0.000000 -0.426100
# 181                 2      0.949369        0.000000        0.999999 -1.104083
# 182                 1      0.615390        0.774350        0.000000 -2.844080
# 183                 1      0.514168        0.463475        0.000000 -1.586194
# 184                 2      0.843289        0.000000        0.999998  1.125679
# 185                 1      0.306228        0.520175        0.000000 -1.943511
# 186                 2      0.702252        0.000000        0.999957 -0.369498
# 187                 2      0.931889        0.000000        0.999999  2.509733
# 188                 1      0.793036        0.898923        0.000000  1.098202
# 189                 1      0.585939        0.757312        0.000000 -0.379622
# 190                 0      0.860023        0.000000        0.000000 -1.129421
# 191                 0      0.811488        0.000000        0.000000  1.641053
# 192                 2      0.828711        0.000000        0.999923 -0.651815
# 193                 1      0.193875        0.558617        0.000000  2.352219
# 194                 0      0.788331        0.000000        0.000000  1.996295
# 195                 1      0.783168        0.887991        0.000000 -2.695523
# 196                 1      0.650817        0.707491        0.000000 -2.994643
# 197                 2      0.984082        0.000000        0.999998 -0.796120
# 198                 1      0.640212        0.729821        0.000000  2.383199
# 199                 1      0.848935        0.738672        0.000000 -2.569808
#
#          PFMET        Z1Pt                                         JetPt  \
# 0    16.451096  201.461288                   [253.798, 50.7102, 27.4577]
# 1    21.007767  128.747757                            [31.1261, 22.4956]
# 2    27.834196  118.391632                                            []
# 3    34.454174  120.855667                   [142.196, 100.241, 39.1497]
# 4    34.997581   60.197628                                      [21.159]
# 5    11.164874   44.724720                    [107.07, 83.3726, 69.0321]
# 6    24.769041   29.502363                                            []
# 7    40.353863   12.673450                                     [54.3499]
# 8    39.022423  150.693405                            [248.889, 20.3388]
# 9    27.509668   53.723461                            [110.089, 40.0421]
# 10   23.498978   51.774239                                     [57.4829]
# 11   45.445148   30.836380                            [53.5397, 22.9587]
# 12   85.116264   32.976570                                            []
# 13   24.968744   13.126985                                     [25.8678]
# 14   48.037773   51.648796                                            []
# 15   22.531975   68.830658                                     [141.999]
# 16   10.627840   40.754280                                     [93.4044]
# 17   18.398380  186.637604                                       [221.3]
# 18   49.723511   74.291656                            [66.9802, 62.7345]
# 19   33.747711   98.912605                            [219.723, 75.8526]
# 20   29.165466   31.802013                             [85.695, 21.7167]
# 21   26.623787   76.106682          [81.9283, 58.3575, 44.6746, 31.5659]
# 22   18.727764   40.476162                                     [70.2575]
# 23   55.114895   48.921150                                            []
# 24   35.633305   36.984898                                            []
# 25   11.851804   58.292477                                     [59.7141]
# 26   26.466230   71.418953                                            []
# 27   35.662300  117.120064  [132.11, 38.3628, 33.6303, 27.8153, 20.5438]
# 28   55.100006  170.427399   [278.753, 75.563, 25.976, 23.7306, 20.8918]
# 29   21.244928  121.830551                            [248.806, 49.1401]
# ..         ...         ...                                           ...
# 170  13.711347   31.631649                             [95.031, 51.0998]
# 171  16.368725   27.794939                                     [23.0866]
# 172  38.280109   51.877159                                     [39.3842]
# 173  68.488632  201.640930                                     [115.841]
# 174  12.406890  119.959549                            [144.567, 67.4449]
# 175  36.907894   45.495205          [83.1641, 63.8573, 28.1589, 23.6381]
# 176  37.307251  119.672760                            [108.327, 54.7482]
# 177  29.868196   51.104080                             [30.2108, 24.935]
# 178  60.781338  116.969772                                     [146.603]
# 179  27.066803   34.496845                   [42.8925, 34.0551, 22.8623]
# 180  35.310947   37.315819                                      [28.441]
# 181  37.669331    4.164855                            [94.8794, 43.7206]
# 182   9.242163  108.554771                                     [74.2387]
# 183  36.088081   45.729576                                       [66.17]
# 184  10.895762   62.220188                            [75.8906, 56.4782]
# 185   7.833156   24.198584                                     [39.9626]
# 186   9.832058   48.031223                            [45.4008, 40.0176]
# 187   8.782928   26.238932                             [77.151, 55.8557]
# 188  47.922424   65.847221                                     [46.4275]
# 189  44.240768   56.216869                                     [67.2864]
# 190  25.109804   53.477673                                     [29.7236]
# 191  33.629608   12.901216                                     [27.1203]
# 192  23.051298  205.242844                   [219.526, 35.3081, 26.3063]
# 193  11.081025   25.851368                                     [34.1338]
# 194  43.467411   35.603268                                            []
# 195  29.813932   73.391953                                     [103.886]
# 196  24.215151   75.218437                                     [66.3019]
# 197  26.201920   18.628967                            [110.147, 80.1446]
# 198  60.243515   27.134249                                     [67.9974]
# 199  22.193348   79.146660                              [99.345, 27.379]
#
#                                                 JetPhi  D_ZHh_ggH_ME  \
# 0                         [1.24006, 0.425453, 2.59064]  1.292088e-08
# 1                                   [2.66515, 3.02946]  0.000000e+00
# 2                                                   []  0.000000e+00
# 3                         [0.98874, 2.7784, -0.907428]  1.007721e-04
# 4                                         [-0.0723124]  0.000000e+00
# 5                       [1.42306, -1.65973, -0.729264]  3.167858e-02
# 6                                                   []  0.000000e+00
# 7                                          [-0.239922]  0.000000e+00
# 8                                  [1.43787, -2.77113]  0.000000e+00
# 9                                  [1.03233, -3.01447]  7.101816e-05
# 10                                          [-1.83691]  0.000000e+00
# 11                                 [1.16713, -2.72893]  0.000000e+00
# 12                                                  []  0.000000e+00
# 13                                         [-0.782166]  0.000000e+00
# 14                                                  []  0.000000e+00
# 15                                           [2.98603]  0.000000e+00
# 16                                           [2.61953]  0.000000e+00
# 17                                        [-0.0298153]  0.000000e+00
# 18                               [-0.778209, -0.18954]  2.598302e-04
# 19                                 [3.11965, 0.188674]  3.340186e-06
# 20                                 [1.62302, 0.691995]  0.000000e+00
# 21                [-0.37845, 1.03222, 2.91961, 2.6103]  3.273810e-03
# 22                                          [-1.15241]  0.000000e+00
# 23                                                  []  0.000000e+00
# 24                                                  []  0.000000e+00
# 25                                           [2.35508]  0.000000e+00
# 26                                                  []  0.000000e+00
# 27   [0.703039, 0.0413076, -1.3107, 0.920014, -2.17...  8.257283e-07
# 28   [-1.62418, 0.870042, -0.916796, 0.935308, -0.1...  5.396103e-04
# 29                                [-2.42976, 0.492476]  4.621719e-04
# ..                                                 ...           ...
# 170                               [0.991834, -2.28309]  4.923061e-06
# 171                                          [2.65177]  0.000000e+00
# 172                                          [1.68233]  0.000000e+00
# 173                                         [-2.71217]  0.000000e+00
# 174                                [-3.01028, 1.47354]  9.976518e-07
# 175          [-3.09387, -0.910576, -1.31452, -1.27561]  1.660239e-04
# 176                               [-2.18842, -2.15785]  3.698762e-04
# 177                                 [1.86199, 2.80083]  0.000000e+00
# 178                                          [2.38333]  0.000000e+00
# 179                     [-0.361682, -1.24208, 2.89815]  3.483587e-04
# 180                                        [-0.908404]  0.000000e+00
# 181                                [1.27094, -1.95331]  3.397879e-07
# 182                                        [0.0974814]  0.000000e+00
# 183                                          [2.12897]  0.000000e+00
# 184                               [-2.06708, -2.05076]  4.129876e-07
# 185                                          [1.05367]  0.000000e+00
# 186                                 [1.55297, 2.70885]  3.923355e-06
# 187                               [-0.456432, 2.71177]  2.401766e-08
# 188                                         [-2.18125]  0.000000e+00
# 189                                          [2.56392]  0.000000e+00
# 190                                           [2.1064]  0.000000e+00
# 191                                         [-1.29947]  0.000000e+00
# 192                      [2.37155, -2.85498, -2.30028]  1.305865e-05
# 193                                        [-0.485501]  0.000000e+00
# 194                                                 []  0.000000e+00
# 195                                        [0.0173173]  0.000000e+00
# 196                                       [0.00159153]  0.000000e+00
# 197                               [2.51026, -0.547131]  2.468910e-07
# 198                                        [-0.867767]  0.000000e+00
# 199                               [0.892934, 0.321977]  0.000000e+00
#
#          ...       D_VBF2j_ZHh_ME        ZZPt     Z1Mass  D_WHh_ZHh_ME  \
# 0        ...             1.000000  285.365845  80.809822      0.767074
# 1        ...             0.000000  171.799011  75.432785      0.000000
# 2        ...             0.000000  145.398026  88.388725      0.000000
# 3        ...             0.999996  164.435593  94.944756      0.965085
# 4        ...             0.000000   45.562355  88.106888      0.000000
# 5        ...             0.958056   68.835289  89.576668      0.858479
# 6        ...             0.000000   45.514187  83.453056      0.000000
# 7        ...             0.000000   41.328495  84.156403      0.000000
# 8        ...             0.000000  215.297104  91.460945      0.000000
# 9        ...             0.999978   80.342834  92.266899      0.956768
# 10       ...             0.000000   46.801563  57.951084      0.000000
# 11       ...             0.000000   27.470245  88.834412      0.000000
# 12       ...             0.000000   26.714691  91.380043      0.000000
# 13       ...             0.000000   15.773579  91.321915      0.000000
# 14       ...             0.000000  121.408707  73.740242      0.000000
# 15       ...             0.000000  158.312363  81.170975      0.000000
# 16       ...             0.000000   39.732517  92.473976      0.000000
# 17       ...             0.000000  201.640274  89.122246      0.000000
# 18       ...             0.999945   96.437561  89.957359      0.892305
# 19       ...             0.999999  152.669800  73.084679      0.994398
# 20       ...             0.000000  103.207527  79.118217      0.000000
# 21       ...             0.999767   95.825272  95.864326      0.801757
# 22       ...             0.000000   83.812027  88.247681      0.000000
# 23       ...             0.000000   62.603458  90.219307      0.000000
# 24       ...             0.000000   26.385529  89.165588      0.000000
# 25       ...             0.000000   80.460793  87.569061      0.000000
# 26       ...             0.000000   81.780334  94.683655      0.000000
# 27       ...             1.000000  181.846542  54.541763      0.992858
# 28       ...             0.999479  211.573471  93.374443      0.937880
# 29       ...             0.999643  149.750992  77.292015      0.936759
# ..       ...                  ...         ...        ...           ...
# 170      ...             0.999999   29.334452  61.210361      0.965930
# 171      ...             0.000000   40.072605  88.637962      0.000000
# 172      ...             0.000000   44.871319  67.878014      0.000000
# 173      ...             0.000000  239.409348  51.110916      0.000000
# 174      ...             1.000000  134.468491  94.529358      0.967670
# 175      ...             0.999981   88.467888  88.573463      0.977477
# 176      ...             0.999817  189.307770  90.586540      0.914912
# 177      ...             0.000000   62.917614  78.215576      0.000000
# 178      ...             0.000000  155.307861  85.035652      0.000000
# 179      ...             0.507760   17.406395  62.914276      0.991701
# 180      ...             0.000000   29.135025  93.922729      0.000000
# 181      ...             1.000000    4.961689  88.102119      0.957211
# 182      ...             0.000000  108.190147  76.711182      0.000000
# 183      ...             0.000000   59.948174  85.299538      0.000000
# 184      ...             1.000000  158.890808  72.974693      0.969691
# 185      ...             0.000000   37.545372  86.565514      0.000000
# 186      ...             1.000000   48.169598  93.752121      0.992555
# 187      ...             1.000000   46.379963  61.561676      0.994525
# 188      ...             0.000000  105.795204  95.537888      0.000000
# 189      ...             0.000000   61.518906  80.329910      0.000000
# 190      ...             0.000000   67.373146  91.403946      0.000000
# 191      ...             0.000000   60.381500  66.036560      0.000000
# 192      ...             0.999997  282.674805  93.355804      0.957119
# 193      ...             0.000000   47.507313  87.975266      0.000000
# 194      ...             0.000000   60.739452  90.504234      0.000000
# 195      ...             0.000000   81.855408  90.343239      0.000000
# 196      ...             0.000000   65.168709  85.355301      0.000000
# 197      ...             1.000000   42.978645  86.533707      0.987385
# 198      ...             0.000000   58.829727  91.825394      0.000000
# 199      ...             0.000000  128.036499  92.115204      0.000000
#
#         ZZEta  ZZMassErr                                             JetEta  \
# 0    1.717359   3.386536                      [-3.16792, 3.33127, -2.71497]
# 1   -1.171434   1.153660                              [-0.382805, 0.150642]
# 2    0.480447   0.976387                                                 []
# 3    0.481628   1.055473                       [1.51297, -2.8085, -2.58724]
# 4    1.047899   1.321407                                          [1.86964]
# 5   -0.212605   2.444617                      [1.97583, 0.141352, -0.32727]
# 6    1.445345   0.742779                                                 []
# 7    2.531489   1.107818                                           [2.3265]
# 8    0.719072   1.558875                               [0.986152, -2.69625]
# 9    0.805167   1.822306                                [-2.42117, 1.58926]
# 10  -1.473718   2.059940                                         [-3.56218]
# 11  -1.605144   1.595253                                 [-2.5997, 1.02863]
# 12  -0.257203   1.495259                                                 []
# 13   2.754176   1.689482                                          [4.02931]
# 14   1.587511   2.365772                                                 []
# 15  -0.580547   2.148549                                         [-1.36296]
# 16  -0.584388   1.094015                                           [2.3779]
# 17  -1.641164   2.885734                                         [0.565215]
# 18  -1.561912   1.932333                                [-2.86443, 1.08895]
# 19   1.814755   1.391715                                [2.58685, -1.98206]
# 20   0.978840   0.874240                                [0.971003, -2.8185]
# 21  -2.171495   2.958064             [-2.55596, 1.24062, -2.79474, 2.81736]
# 22   1.116439   0.705316                                          [3.58488]
# 23   2.635280   1.730494                                                 []
# 24   1.370464   0.826857                                                 []
# 25  -1.150797   1.019059                                          [1.59426]
# 26  -0.470679   0.969871                                                 []
# 27   1.615016   1.704279  [-2.52709, 2.44587, -1.17611, 2.41975, -0.489252]
# 28   0.143361   1.372242  [-0.132636, 2.89565, 1.88811, 1.82931, -0.990226]
# 29   0.225322   1.107500                                [1.47134, -1.59245]
# ..        ...        ...                                                ...
# 170 -2.053486   1.683554                                [2.19036, -2.75607]
# 171 -0.454349   1.282073                                           [2.3746]
# 172  2.093434   1.293248                                          [4.62825]
# 173  0.367742   1.171482                                          [3.31698]
# 174 -0.424170   1.089696                                 [-2.69099, 3.6741]
# 175 -1.249532   1.238403             [-1.93659, 2.07814, -3.56308, 2.55654]
# 176  0.388087   0.779315                                 [-1.8394, 1.77077]
# 177 -2.245047   1.845920                                [1.92437, -3.48243]
# 178 -0.843315   0.870084                                          [1.08202]
# 179  1.809082   0.822823                         [2.6612, 3.64736, 1.28076]
# 180 -0.008171   0.859394                                          [0.82598]
# 181  3.503272   2.539997                                [1.88142, -3.93383]
# 182 -1.156791   2.231448                                         [-2.14756]
# 183  0.339518   2.001018                                         [-1.00051]
# 184 -1.069808   1.314558                                [3.24153, -3.05713]
# 185  2.675440   2.385513                                         [-3.26823]
# 186  0.851468   0.824558                                [-1.76084, 3.86077]
# 187  2.260334   0.903632                                [2.14709, -4.05387]
# 188 -0.616892   2.476874                                         [-3.77559]
# 189 -0.174369   1.903074                                         [-2.76041]
# 190  0.583426   0.811836                                         [-3.67807]
# 191 -1.465841   1.076999                                         [0.358926]
# 192  1.708844   1.839144                      [-0.779608, 4.34453, 2.35418]
# 193 -0.151373   0.857420                                          [1.83493]
# 194  2.083508   1.310195                                                 []
# 195  2.559919   2.022699                                          [4.13774]
# 196 -1.071684   1.387232                                          [2.62865]
# 197  1.220951   1.533222                                [3.59531, -2.42836]
# 198 -0.007719   1.861482                                         [-2.81335]
# 199 -1.510081   1.424531                                [3.26998, -3.26651]
#
#     D_VBF2j_ggH_ME       Z2Pt  D_WHh_ggH_ME
# 0         0.886270  83.986824  4.255110e-08
# 1         0.000000  51.472225  0.000000e+00
# 2         0.000000  28.689997  0.000000e+00
# 3         0.963501  43.982029  2.777999e-03
# 4         0.000000  16.421841  0.000000e+00
# 5         0.427671  24.707504  1.655899e-01
# 6         0.000000  30.615452  0.000000e+00
# 7         0.000000  32.675678  0.000000e+00
# 8         0.000000  65.072563  0.000000e+00
# 9         0.767432  27.719597  1.569353e-03
# 10        0.000000  10.174569  0.000000e+00
# 11        0.000000   6.251887  0.000000e+00
# 12        0.000000   6.321743  0.000000e+00
# 13        0.000000  22.693007  0.000000e+00
# 14        0.000000  70.125374  0.000000e+00
# 15        0.000000  89.518684  0.000000e+00
# 16        0.000000   1.124728  0.000000e+00
# 17        0.000000  22.996582  0.000000e+00
# 18        0.824398  25.065369  2.148749e-03
# 19        0.718313  54.887020  5.925566e-04
# 20        0.000000  71.538383  0.000000e+00
# 21        0.933773  22.955832  1.310968e-02
# 22        0.000000  49.101437  0.000000e+00
# 23        0.000000  29.798576  0.000000e+00
# 24        0.000000  10.664112  0.000000e+00
# 25        0.000000  28.790625  0.000000e+00
# 26        0.000000  21.846127  0.000000e+00
# 27        0.726945  65.685760  1.147778e-04
# 28        0.508832  41.174732  8.085496e-03
# 29        0.563905  28.485781  6.802485e-03
# ..             ...        ...           ...
# 170       0.817140  23.009012  1.395552e-04
# 171       0.000000  12.413471  0.000000e+00
# 172       0.000000  15.331192  0.000000e+00
# 173       0.000000  38.200603  0.000000e+00
# 174       0.985610  22.102814  2.985959e-05
# 175       0.894989  43.047329  7.154870e-03
# 176       0.668571  74.679825  3.962828e-03
# 177       0.000000  25.934010  0.000000e+00
# 178       0.000000  38.512173  0.000000e+00
# 179       0.000359  21.679075  3.997865e-02
# 180       0.000000  15.005020  0.000000e+00
# 181       0.860287   2.967906  7.601157e-06
# 182       0.000000  24.840767  0.000000e+00
# 183       0.000000  16.802357  0.000000e+00
# 184       0.893846  98.059502  1.321276e-05
# 185       0.000000  13.980510  0.000000e+00
# 186       0.924558   1.647848  5.228043e-04
# 187       0.808550  20.174522  4.362925e-06
# 188       0.000000  41.640800  0.000000e+00
# 189       0.000000  15.147421  0.000000e+00
# 190       0.000000  29.241180  0.000000e+00
# 191       0.000000  47.525249  0.000000e+00
# 192       0.790319  78.995567  2.913929e-04
# 193       0.000000  31.882381  0.000000e+00
# 194       0.000000  25.263763  0.000000e+00
# 195       0.000000  27.802532  0.000000e+00
# 196       0.000000  10.961981  0.000000e+00
# 197       0.889607  26.890162  1.932370e-05
# 198       0.000000  32.274021  0.000000e+00
# 199       0.000000  52.332813  0.000000e+00
#
# [200 rows x 21 columns]

# %%
random_data = generate_random_input(column_names, fixed_input)
evaluate_model(model, pre, random_data)
# Out:
# 0.11812268197536469

# %%
list_inputs = ["JetPt", "JetPhi", "JetEta"]

# %%
def generate_random_input(input_columns, fixed_input):
    generated_input = {}
    
    for column_name in input_columns:
        var_low = variable_ranges[column_name][0]
        var_high = variable_ranges[column_name][1]
        
        if column_name in list_inputs:
            generated_input[column_name] = np.random.uniform(var_low, var_high, 4)
        else:
            generated_input[column_name] = np.random.uniform(var_low, var_high)
    
    generated_input.update(fixed_input)
    
    return generated_input

# %%
def evaluate_model_batch(model, pre, queue_df):
    pre_data = pre.process(queue_df)
    
    output = model.get_keras_model().predict(x = pre_data, verbose = 0, batch_size = len(pre_data))
    return output

# %%
def add_to_queue(queue, input_list, input_columns, fixed_input):
    queue = queue.append(fill_inputs_from_list(input_columns, input_list, fixed_input), ignore_index = True)
    return queue

# %%
def evaluate_model(model, pre, input_dict):
    df = pd.DataFrame()
    df = df.append(input_dict, ignore_index = True)
    pre_data = pre.process(df)
        
    output = model.get_keras_model().predict(x = pre_data, verbose = 0, batch_size = len(pre_data))
    return np.asscalar(output)

# %%
def fill_inputs_from_list(input_columns, input_list, fixed_input):
    generated_input = {}
    
    i = 0
    for column_name in input_columns:
        if column_name in list_inputs:
            generated_input[column_name] = np.array(input_list[i : i + 4])
            i += 4
        else:
            generated_input[column_name] = input_list[i]
            i += 1
    
    generated_input.update(fixed_input)
    
    return generated_input

# %%
def convert_inputs_to_list(input_columns, input_dict):
    generated_list = []

    for column_name in input_columns:
        if column_name in list_inputs:
            generated_list += input_dict[column_name].tolist()
        else:
            generated_list.append(input_dict[column_name])
            
    return generated_list

# %%
def evaluate_model_list(model, pre, input_list, input_columns, fixed_input):
    queue = pd.DataFrame()
    queue = add_to_queue(queue, input_list, input_columns, fixed_input)
    
    return evaluate_model_batch(model, pre, queue)

# %%
def compute_gradient(model, pre, inputs, column_names, fixed_input):
    eps = 1e-2
    
    gradient = []
    
    queue = pd.DataFrame()
    
    for i in range(len(inputs)):
        upper = list(inputs)
        upper[i] += eps
        
        lower = list(inputs)
        lower[i] -= eps
        
        queue = add_to_queue(queue, upper, column_names, fixed_input)
        queue = add_to_queue(queue, lower, column_names, fixed_input)
        
    outputs = evaluate_model_batch(model, pre, queue).flatten()
    
    i = 0
    while i < len(outputs):    
        gradient.append((outputs[i] - outputs[i + 1]) / (2 * eps))
        i += 2
        
    return gradient

# %%
def ga(model, pre, column_names, fixed_input, threshold, max_iterations = 200):
    cur_input = convert_inputs_to_list(column_names, generate_random_input(column_names, fixed_input))
    
    stepsize = 1.0
    
    for i in range(max_iterations):
        gradient = compute_gradient(model, pre, cur_input, column_names, fixed_input)
        cur_input = [cur_val + stepsize * grad_val for cur_val, grad_val in zip(cur_input, gradient)]
        
        model_output = evaluate_model_list(model, pre, cur_input, column_names, fixed_input)
        
        if model_output > threshold:
            break
        
    print "final output = " + str(model_output)
        
    return fill_inputs_from_list(column_names, cur_input, fixed_input)

# %%
num_contour_evaluations = 200

# %%
for ii in range(num_contour_evaluations):

# %%
eta0s = []
eta1s = []
pt0s = []
pt1s = []
ZZetas = []

# %%
for ii in range(num_contour_evaluations):
    contour = ga(model, pre, column_names, fixed_input, threshold = 0.9)
    
    # now need to extract the values for the plot: eta1 vs. eta2
    pts = contour["JetPt"]
    etas = contour["JetEta"]
    ZZeta = contour["ZZEta"]
    pt_sorted = np.flipud(np.argsort(pts))
    eta0 = etas[pt_sorted[0]]
    eta1 = etas[pt_sorted[1]]
    pt0 = pts[pt_sorted[0]]
    pt1 = pts[pt_sorted[1]]
    
    print "pt0 = " + str(pt0) + ", pt1 = " + str(pt1)
    print "eta0 = " + str(eta0) + ", eta1 = " + str(eta1)
     
    eta0s.append(eta0)
    eta1s.append(eta1)
    pt0s.append(pt0)
    pt1s.append(pt1)
    ZZetas.append(ZZeta)
# Out:
# final output = [[ 0.9625203]]
# pt0 = 389.060682852, pt1 = 151.375473178
# eta0 = 0.0224326897007, eta1 = -0.58032789584
# final output = [[ 0.95640117]]
# pt0 = 476.270468147, pt1 = 231.193216729
# eta0 = 1.87162097626, eta1 = -1.6609821343
# final output = [[ 0.9999764]]
# pt0 = 461.009697587, pt1 = 201.144008537
# eta0 = 0.766007640169, eta1 = -0.807251364739
# final output = [[ 0.95759434]]
# pt0 = 449.196187972, pt1 = 425.586401899
# eta0 = -1.01981094826, eta1 = -1.04923519856
# final output = [[ 1.]]
# pt0 = 386.894693459, pt1 = 238.966358077
# eta0 = -1.62928110696, eta1 = 1.78248062493
# final output = [[ 0.93943703]]
# pt0 = 467.037778046, pt1 = 453.052464588
# eta0 = -0.00706918689148, eta1 = 0.075189181899
# final output = [[ 0.9112162]]
# pt0 = 479.625773668, pt1 = 383.347082881
# eta0 = -2.03222923174, eta1 = 0.908259881314
# final output = [[ 0.99927086]]
# pt0 = 325.512240297, pt1 = 227.776191996
# eta0 = -1.54440009184, eta1 = -0.0430038526993
# final output = [[ 0.92308187]]
# pt0 = 409.860291152, pt1 = 383.014200375
# eta0 = -0.715051486025, eta1 = -1.25665701624
# final output = [[ 0.99943048]]
# pt0 = 358.980209608, pt1 = 311.902224289
# eta0 = 0.934045360867, eta1 = 0.620501788018
# final output = [[ 0.90492886]]
# pt0 = 463.125635807, pt1 = 451.156714032
# eta0 = -1.6009602853, eta1 = 0.134731094709
# final output = [[ 1.]]
# pt0 = 310.155490717, pt1 = 278.385070939
# eta0 = -0.0457200285738, eta1 = -0.029629701275
# final output = [[ 0.9881444]]
# pt0 = 476.277315091, pt1 = 166.155636884
# eta0 = 1.58406790054, eta1 = 1.15393906549
# final output = [[ 0.99995136]]
# pt0 = 306.121024509, pt1 = 302.706048996
# eta0 = 0.996032843881, eta1 = -1.90629704263
# final output = [[ 0.9999373]]
# pt0 = 488.771549845, pt1 = 416.444806743
# eta0 = -0.856521667622, eta1 = 1.66378568303
# final output = [[ 1.]]
# pt0 = 300.431009303, pt1 = 158.825297022
# eta0 = -1.03749178158, eta1 = 1.21814753042
# final output = [[ 0.94508624]]
# pt0 = 447.410102723, pt1 = 442.398990816
# eta0 = -1.33470473943, eta1 = 1.67969055334
# final output = [[ 0.99361438]]
# pt0 = 394.415897799, pt1 = 354.564008785
# eta0 = 1.29216851535, eta1 = -1.44629317024
# final output = [[ 0.96676666]]
# pt0 = 493.938113111, pt1 = 464.372748302
# eta0 = 1.42633733917, eta1 = 1.51082652955
# final output = [[ 0.99620581]]
# pt0 = 368.543092067, pt1 = 300.234181476
# eta0 = -0.142773671913, eta1 = -0.766711929682
# final output = [[ 0.99999189]]
# pt0 = 211.417291687, pt1 = 174.052058533
# eta0 = -1.71120738416, eta1 = -1.8455779688
# final output = [[ 0.99996948]]
# pt0 = 145.226880277, pt1 = 113.803678555
# eta0 = 1.00889032209, eta1 = -0.659735129078
# final output = [[ 0.99941278]]
# pt0 = 457.997488871, pt1 = 270.740368366
# eta0 = -1.58079642149, eta1 = 1.17036373274
# final output = [[ 0.99941778]]
# pt0 = 248.820890935, pt1 = 233.729046775
# eta0 = 0.674328982551, eta1 = 1.42348381975
# final output = [[ 0.9292261]]
# pt0 = 369.250006941, pt1 = 305.1075526
# eta0 = -0.675186448314, eta1 = -0.0246685098563
# final output = [[ 0.98080349]]
# pt0 = 461.730575048, pt1 = 342.569461542
# eta0 = -1.76698921945, eta1 = -1.7438409845
# final output = [[ 0.98418713]]
# pt0 = 485.708210529, pt1 = 456.583658374
# eta0 = 1.33352898723, eta1 = 0.480896264009
# final output = [[ 0.99845254]]
# pt0 = 258.279563418, pt1 = 195.294849676
# eta0 = -1.27120107993, eta1 = 1.56156857567
# final output = [[ 0.92567003]]
# pt0 = 432.457463853, pt1 = 367.405940933
# eta0 = 1.89710416723, eta1 = 1.06151710053
# final output = [[ 0.99983573]]
# pt0 = 342.208335949, pt1 = 239.741951016
# eta0 = 1.09581776002, eta1 = -0.587654218639
# final output = [[ 0.95383924]]
# pt0 = 302.314185518, pt1 = 222.92892726
# eta0 = -0.324742696154, eta1 = 0.400252818908
# final output = [[ 0.9972626]]
# pt0 = 269.394833583, pt1 = 204.401525118
# eta0 = -0.20179090224, eta1 = -1.20461104329
# final output = [[ 0.99999988]]
# pt0 = 481.133710149, pt1 = 334.060164937
# eta0 = 0.284859510396, eta1 = -0.303973368449
# final output = [[ 1.]]
# pt0 = 471.203794223, pt1 = 100.746651892
# eta0 = 1.17850787618, eta1 = -1.09638589903
# final output = [[ 1.]]
# pt0 = 454.912581371, pt1 = 109.77189625
# eta0 = -0.139743366307, eta1 = 1.77867129351
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-105-a9c124994433> in <module>()
#       1 for ii in range(num_contour_evaluations):
# ----> 2     contour = ga(model, pre, column_names, fixed_input, threshold = 0.9)
#       3
#       4     # now need to extract the values for the plot: eta1 vs. eta2
#       5     pts = contour["JetPt"]
#
# <ipython-input-37-934b2eb8d930> in ga(model, pre, column_names, fixed_input, threshold, max_iterations)
#       5
#       6     for i in range(max_iterations):
# ----> 7         gradient = compute_gradient(model, pre, cur_input, column_names, fixed_input)
#       8         cur_input = [cur_val + stepsize * grad_val for cur_val, grad_val in zip(cur_input, gradient)]
#       9
#
# <ipython-input-36-71046a1942d2> in compute_gradient(model, pre, inputs, column_names, fixed_input)
#      16         queue = add_to_queue(queue, lower, column_names, fixed_input)
#      17
# ---> 18     outputs = evaluate_model_batch(model, pre, queue).flatten()
#      19
#      20     i = 0
#
# <ipython-input-30-16f6c4aa6192> in evaluate_model_batch(model, pre, queue_df)
#       1 def evaluate_model_batch(model, pre, queue_df):
# ----> 2     pre_data = pre.process(queue_df)
#       3
#       4     output = model.get_keras_model().predict(x = pre_data, verbose = 0, batch_size = len(pre_data))
#       5     return output
#
# /grid_mnt/vol__vol_U__u/llr/cms/wind/cmssw/CMSSW_9_4_2/src/ZZAnalysis/AnalysisStep/test/Python/trainlib/FlexiblePCAWhiteningPreprocessor.pyc in process(self, data)
#      89         self.last_indices = cut_data.index
#      90
# ---> 91         prepared_data = self.prepare_data(cut_data)
#      92
#      93         return self.base_preprocessor.process(prepared_data)
#
# /grid_mnt/vol__vol_U__u/llr/cms/wind/cmssw/CMSSW_9_4_2/src/ZZAnalysis/AnalysisStep/test/Python/trainlib/FlexiblePCAWhiteningPreprocessor.pyc in prepare_data(self, data)
#     121         for column in self.nonperiodic_columns:
#     122             #print "nonperiodic column: " + column
# --> 123             cf = self.extract_column(data, column)
#     124             prepared_data = pd.concat([prepared_data, cf], axis = 1)
#     125
#
# /grid_mnt/vol__vol_U__u/llr/cms/wind/cmssw/CMSSW_9_4_2/src/ZZAnalysis/AnalysisStep/test/Python/trainlib/FlexiblePCAWhiteningPreprocessor.pyc in extract_column(self, df, colstring)
#     180             col, sorted_col_order, _ = re.split('[\[\]]', colstring)
#     181             sorted_col, order = re.split('\|', sorted_col_order)
# --> 182             cf = self.extract_order_filtered(df, sorted_col, [col], int(order))
#     183         else:
#     184             cf = df[[colstring]]
#
# /grid_mnt/vol__vol_U__u/llr/cms/wind/cmssw/CMSSW_9_4_2/src/ZZAnalysis/AnalysisStep/test/Python/trainlib/FlexiblePCAWhiteningPreprocessor.pyc in extract_order_filtered(self, df, sorted_column, columns, order)
#     164     def extract_order_filtered(self, df, sorted_column, columns, order):
#     165         if len(df) > 0:
# --> 166             extracted_raw = self.extract_order(df, sorted_column, columns, order)
#     167
#     168             if any("Jet" in col for col in extracted_raw.columns):
#
# /grid_mnt/vol__vol_U__u/llr/cms/wind/cmssw/CMSSW_9_4_2/src/ZZAnalysis/AnalysisStep/test/Python/trainlib/FlexiblePCAWhiteningPreprocessor.pyc in extract_order(self, df, sorted_column, columns, order)
#     156         extracted_cols = pd.DataFrame()
#     157         for column in columns:
# --> 158             extracted_col = pd.DataFrame(df_temp.transform(lambda row: get_element(row, column), axis = 1, raw = True))
#     159             extracted_col.columns = [column + "_" + str(order)]
#     160             extracted_cols = pd.concat([extracted_cols, extracted_col], axis = 1)
#
# /cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs_depscipy/3.0-fmblme3/lib/python2.7/site-packages/pandas/core/generic.pyc in transform(self, func, *args, **kwargs)
#    6218         @Appender(_shared_docs['transform'] % _shared_doc_kwargs)
#    6219         def transform(self, func, *args, **kwargs):
# -> 6220             result = self.agg(func, *args, **kwargs)
#    6221             if is_scalar(result) or len(result) != len(self):
#    6222                 raise ValueError("transforms cannot produce "
#
# /cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs_depscipy/3.0-fmblme3/lib/python2.7/site-packages/pandas/core/frame.pyc in aggregate(self, func, axis, *args, **kwargs)
#    4152                 pass
#    4153         if result is None:
# -> 4154             return self.apply(func, axis=axis, args=args, **kwargs)
#    4155         return result
#    4156
#
# /cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs_depscipy/3.0-fmblme3/lib/python2.7/site-packages/pandas/core/frame.pyc in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# /cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs_depscipy/3.0-fmblme3/lib/python2.7/site-packages/pandas/core/frame.pyc in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4316                     labels = self._get_agg_axis(axis)
#    4317                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# -> 4318                                         labels=labels)
#    4319                     return Series(result, index=labels)
#    4320                 except Exception:
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.reduce (pandas/_libs/lib.c:44036)()
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.Reducer.get_result (pandas/_libs/lib.c:33629)()
#
# /grid_mnt/vol__vol_U__u/llr/cms/wind/cmssw/CMSSW_9_4_2/src/ZZAnalysis/AnalysisStep/test/Python/trainlib/FlexiblePCAWhiteningPreprocessor.pyc in <lambda>(row)
#     156         extracted_cols = pd.DataFrame()
#     157         for column in columns:
# --> 158             extracted_col = pd.DataFrame(df_temp.transform(lambda row: get_element(row, column), axis = 1, raw = True))
#     159             extracted_col.columns = [column + "_" + str(order)]
#     160             extracted_cols = pd.concat([extracted_cols, extracted_col], axis = 1)
#
# /grid_mnt/vol__vol_U__u/llr/cms/wind/cmssw/CMSSW_9_4_2/src/ZZAnalysis/AnalysisStep/test/Python/trainlib/FlexiblePCAWhiteningPreprocessor.pyc in get_element(row, column_name)
#     152                 return 0
#     153             else:
# --> 154                 return row[column_name][row["list_index"]]
#     155
#     156         extracted_cols = pd.DataFrame()
#
# /cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs_depscipy/3.0-fmblme3/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# --> 601             result = self.index.get_value(self, key)
#     602
#     603             if not is_scalar(result):
#
# /cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs_depscipy/3.0-fmblme3/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_value(self, series, key)
#    2472         k = _values_from_object(key)
#    2473
# -> 2474         k = self._convert_scalar_indexer(k, kind='getitem')
#    2475         try:
#    2476             return self._engine.get_value(s, k,
#
# KeyboardInterrupt:

# %%
xedges = np.linspace(variable_ranges["JetPt"][0], variable_ranges["JetPt"][1], 10)
yedges = np.linspace(variable_ranges["JetPt"][0], variable_ranges["JetPt"][1], 10)

# %%
H, xedges, yedges = np.histogram2d(pt0s, pt1s, bins = (xedges, yedges))
plt.imshow(H, interpolation = 'nearest', cmap = 'hot', origin='low', extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
plt.colorbar()
plt.show()

# %%
xedges = np.linspace(variable_ranges["JetEta"][0], variable_ranges["JetEta"][1], 15)
yedges = np.linspace(variable_ranges["JetEta"][0], variable_ranges["JetEta"][1], 15)

# %%
H, xedges, yedges = np.histogram2d(eta0s, eta1s, bins = (xedges, yedges))
plt.imshow(H, interpolation = 'nearest', cmap = 'hot', origin='low', extent=[xedges[0], xedges[-1], yedges[0], yedges[-1]])
plt.colorbar()
plt.show()

# %%
bins = np.linspace(variable_ranges["ZZEta"][0], variable_ranges["ZZEta"][1], 35)

# %%
plt.hist(ZZetas, bins)
# Out:
# (array([ 2.,  1.,  2.,  6.,  6.,  1.,  5.,  3.,  2.,  3.,  1.,  4.,  1.,
#          2.,  5.,  1.,  3.,  3.,  5.,  1.,  5.,  2.,  2.,  4.,  3.,  1.,
#          1.,  2.,  3.,  3.,  2.,  1.,  2.,  4.]),
#  array([-1.        , -0.94117647, -0.88235294, -0.82352941, -0.76470588,
#         -0.70588235, -0.64705882, -0.58823529, -0.52941176, -0.47058824,
#         -0.41176471, -0.35294118, -0.29411765, -0.23529412, -0.17647059,
#         -0.11764706, -0.05882353,  0.        ,  0.05882353,  0.11764706,
#          0.17647059,  0.23529412,  0.29411765,  0.35294118,  0.41176471,
#          0.47058824,  0.52941176,  0.58823529,  0.64705882,  0.70588235,
#          0.76470588,  0.82352941,  0.88235294,  0.94117647,  1.        ]),
#  <a list of 34 Patch objects>)

# %%
plt.show()
