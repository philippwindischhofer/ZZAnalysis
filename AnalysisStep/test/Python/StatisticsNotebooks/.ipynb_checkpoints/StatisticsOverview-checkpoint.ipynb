# %%
import os
import sys
import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import fnmatch

# %%
sys.path.insert(0, '/home/llr/cms/wind/cmssw/CMSSW_9_4_2/src/ZZAnalysis/AnalysisStep/test/Python/')

# %%
from trainlib.ConfigFileHandler import ConfigFileHandler
from trainlib.ModelCollectionConfigFileHandler import ModelCollectionConfigFileHandler
from trainlib.ConfigFileUtils import ConfigFileUtils
# Out:
# Welcome to JupyROOT 6.10/09
# Using TensorFlow backend.

# %%
bin_dir = {"Untagged": 0,
            "VBF1j": 1,
            "VBF2j": 2,
            "VHlept": 3,
            "VHhadr": 4,
            "ttHlept": 5,
            "ttHhadr": 6,
            "VHMET": 7}

# %%
campaign_workspace = "/data_CMS/cms/wind/"
campaign_names = ["180409_MC_weighting_Adam", "180409_no_MC_weights_Adam", "180409_no_MC_weights_Adam_smallbatch", "180406_MC_weighting_Adam", "180406_no_MC_weighting_Adam", "180406_MC_weighting_SGD", "180406_no_MC_weighting_SGD", "180408_no_weights_oldtraining"]

# %%
df = pd.DataFrame()

for campaign_name in campaign_names:
    campaign_dir = campaign_workspace + campaign_name + "/"
    
    for folder, subs, files in os.walk(campaign_dir):
        if fnmatch.fnmatch(folder, "*comp_prior*"):
            values = {}
            
            # try to read the punzi values
            conf = ConfigFileHandler()
            conf.load_configuration(folder + "/Mor18_punzi_comp.conf")
            
            values["campaign"] = folder.replace(campaign_workspace, '')
        
            # load the Punzi values for each category
            for category, bin_number in bin_dir.iteritems():
                values[category] = [float(conf.get_field("Punzi", category))]
                
            df = df.append(pd.DataFrame.from_dict(values))
# Out:
# attempting to load configuration file from /data_CMS/cms/wind/180409_MC_weighting_Adam/input_columns_4/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180409_MC_weighting_Adam/input_columns_4/comp_priors_tree_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180409_MC_weighting_Adam/input_columns_4/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180409_no_MC_weights_Adam/input_columns_4/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180409_no_MC_weights_Adam/input_columns_4/comp_priors_tree_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180409_no_MC_weights_Adam/input_columns_4/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180409_no_MC_weights_Adam_smallbatch/input_columns_4/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180409_no_MC_weights_Adam_smallbatch/input_columns_4/comp_priors_tree_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180409_no_MC_weights_Adam_smallbatch/input_columns_4/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180406_MC_weighting_Adam/input_columns_3/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180406_MC_weighting_Adam/input_columns_3/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180406_no_MC_weighting_Adam/input_columns_3/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180406_no_MC_weighting_Adam/input_columns_3/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_1/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_1/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_1/comp_priors_tree_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_2/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_2/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_2/comp_priors_tree_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_3/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_3/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_3/comp_priors_tree_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_4/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_4/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_4/comp_priors_tree_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_5/comp_priors_rand_KL/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_5/comp_priors_voting/Mor18_punzi_comp.conf
# attempting to load configuration file from /data_CMS/cms/wind/180408_no_weights_oldtraining/input_columns_5/comp_priors_tree_KL/Mor18_punzi_comp.conf

# %%
sorted_datacols = sorted(bin_dir.items(), key = lambda x: x[1])
sorted_datacol_names = [x[0] for x in sorted_datacols]

# %%
punzi_data = df[sorted_datacol_names].as_matrix()
punzi_data = np.transpose(punzi_data)

# %%
inparam_labels = df['campaign'].as_matrix()

# %%
df.apply(lambda row: row['VBF1j'] + row['VBF2j'] + row['VHlept'] + row['VHhadr'] + row['ttHlept'] + row['ttHhadr'] + row['VHMET'] - 7, axis = 1)
# Out:
# 0   -0.379238
# 0   -0.159487
# 0   -2.509318
# 0   -0.107911
# 0   -0.048239
# 0   -1.336398
# 0    0.037297
# 0    0.064085
# 0   -1.598660
# 0   -0.373609
# 0   -2.296801
# 0   -0.322374
# 0   -1.410893
# 0   -0.039041
# 0   -0.450374
# 0   -0.016712
# 0   -0.127664
# 0   -1.077625
# 0   -0.050172
# 0    0.089686
# 0   -0.692462
# 0    0.113038
# 0    0.161655
# 0   -0.569647
# 0    0.181365
# 0    0.210163
# 0   -0.479127
# 0    0.273304
# dtype: float64

# %%
plt.figure(figsize = (15, 10))
plt.imshow(punzi_data, interpolation = 'none', cmap = 'RdYlGn', aspect = 0.6, vmin = 0.8, vmax = 1.2)
plt.colorbar()
plt.yticks(range(len(bin_dir)), sorted_datacol_names)
plt.xticks(range(len(df)), inparam_labels, rotation = 'vertical')
plt.tight_layout()
plt.title("Punzi purity ratio")
#plt.savefig(statistics_dir + "punzi_input_sweep.pdf")
plt.show()
